# %%
import numpy as np
import pandas as pd
import tensorflow.compat.v1 as tf
import os
import sys
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
from collections import deque
import random
import seaborn as sns
sns.set()
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From d:\anaconda\envs\chattel\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
df = pd.read_csv('dataset/GOOG.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2010-08-12  242.212219  247.622620  241.496490  246.251251  246.251251
# 1  2010-08-13  244.744751  245.840836  243.248245  243.418411  243.418411
# 2  2010-08-16  242.082077  245.180176  240.490494  243.038040  243.038040
# 3  2010-08-17  244.509506  247.597595  243.258255  245.505508  245.505508
# 4  2010-08-18  245.465469  245.680679  241.016022  241.316315  241.316315
#
#     Volume
# 0  4404700
# 1  3865500
# 2  2607300
# 3  3777600
# 4  5367400

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1

novelty_search_threshold = 6
novelty_log_maxlen = 1000
backlog_maxsize = 500
novelty_log_add_amount = 3

# %%
class neuralnetwork:
    def __init__(self, id_, hidden_size = 128):
        self.W1 = np.random.randn(window_size, hidden_size) / np.sqrt(window_size)
        self.W2 = np.random.randn(hidden_size, 3) / np.sqrt(hidden_size)
        self.fitness = 0
        self.last_features = None
        self.id = id_

def relu(X):
    return np.maximum(X, 0)
    
def softmax(X):
    e_x = np.exp(X - np.max(X, axis=-1, keepdims=True))
    return e_x / np.sum(e_x, axis=-1, keepdims=True)

def feed_forward(X, nets):
    a1 = np.dot(X, nets.W1)
    z1 = relu(a1)
    a2 = np.dot(z1, nets.W2)
    return softmax(a2)

# %%
class NeuroEvolution:
    def __init__(self, population_size, mutation_rate, model_generator,
                state_size, window_size, trend, skip, initial_money):
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.model_generator = model_generator
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.generation_backlog = []
        self.novel_backlog = []
        self.novel_pop = []
        
    def _initialize_population(self):
        self.population = []
        for i in range(self.population_size):
            self.population.append(self.model_generator(i))
    
    def _memorize(self, q, i, limit):
        q.append(i)
        if len(q) > limit:
            q.pop()
    
    def mutate(self, individual, scale=1.0):
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W1.shape)
        individual.W1 += np.random.normal(loc=0, scale=scale, size=individual.W1.shape) * mutation_mask
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W2.shape)
        individual.W2 += np.random.normal(loc=0, scale=scale, size=individual.W2.shape) * mutation_mask
        return individual
    
    def inherit_weights(self, parent, child):
        child.W1 = parent.W1.copy()
        child.W2 = parent.W2.copy()
        return child
    
    def crossover(self, parent1, parent2):
        child1 = self.model_generator((parent1.id+1)*10)
        child1 = self.inherit_weights(parent1, child1)
        child2 = self.model_generator((parent2.id+1)*10)
        child2 = self.inherit_weights(parent2, child2)
        # first W
        n_neurons = child1.W1.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W1[:, cutoff:] = parent2.W1[:, cutoff:].copy()
        child2.W1[:, cutoff:] = parent1.W1[:, cutoff:].copy()
        # second W
        n_neurons = child1.W2.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W2[:, cutoff:] = parent2.W2[:, cutoff:].copy()
        child2.W2[:, cutoff:] = parent1.W2[:, cutoff:].copy()
        return child1, child2
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def act(self, p, state):
        logits = feed_forward(state, p)
        return np.argmax(logits, 1)[0]
    
    def buy(self, individual,date1,close):
        initial_money = self.initial_money
        starting_money = initial_money
        state = self.get_state(0)
        inventory = []
        states_sell = []
        states_buy = []
        
        for t in range(0, len(close) - 1, self.skip):
            action = self.act(individual, state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(close[t])
                initial_money -= close[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, close[t], initial_money))
                
                df1 = pd.DataFrame({'Date': date1[t+1], 'Close': [close[t+1]],'RESULT': ['Buy'] })
                if not os.path.isfile('output/22.neuro-evolution-novelty-search-agent.csv'):
                    df1.to_csv('output/22.neuro-evolution-novelty-search-agent.csv', index=False)
                else:
                    df1.to_csv('output/22.neuro-evolution-novelty-search-agent.csv', index=False, mode='a', header=False)
                    
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += close[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
                df2 = pd.DataFrame({'Date': date1[t+1], 'Close': [close[t+1]],'RESULT': ['Sell'] })
                if not os.path.isfile('output/22.neuro-evolution-novelty-search-agent.csv'):
                    df2.to_csv('output/22.neuro-evolution-novelty-search-agent.csv', index=False)
                else:
                    df2.to_csv('output/22.neuro-evolution-novelty-search-agent.csv', index=False, mode='a', header=False)
            else:
                print(
                    'day %d, hold UNIT at price %f,  total balance %f,'
                    % (t+1, close[t+1], initial_money)
                )
                df3 = pd.DataFrame({'Date': date1[t+1], 'Close': [close[t+1]], 'RESULT': ['Hold']})
                if not os.path.isfile('output/22.neuro-evolution-novelty-search-agent.csv'):
                    df3.to_csv('output/22.neuro-evolution-novelty-search-agent.csv', index=False)
                else:
                    df3.to_csv('output/22.neuro-evolution-novelty-search-agent.csv', index=False, mode='a', header=False)
            
            state = next_state
            
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
    
    def calculate_fitness(self):
        for i in range(self.population_size):
            initial_money = self.initial_money
            starting_money = initial_money
            state = self.get_state(0)
            inventory = []
            
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(self.population[i], state)
                next_state = self.get_state(t + 1)
            
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    starting_money += self.trend[t]

                state = next_state
            invest = ((starting_money - initial_money) / initial_money) * 100
            self.population[i].fitness = invest
            self.population[i].last_features = self.population[i].W2.flatten()
    
    def evaluate(self, individual, backlog, pop, k = 4):
        score = 0
        if len(backlog):
            x = np.array(backlog)
            nn = NearestNeighbors(n_neighbors = k, metric = 'euclidean').fit(np.array(backlog))
            d, _ = nn.kneighbors([individual])
            score += np.mean(d)
        
        if len(pop):
            nn = NearestNeighbors(n_neighbors = k, metric = 'euclidean').fit(np.array(pop))
            d, _ = nn.kneighbors([individual])
            score += np.mean(d)
        
        return score
    
    def evolve(self, generations=20, checkpoint= 5):
        self._initialize_population()
        n_winners = int(self.population_size * 0.4)
        n_parents = self.population_size - n_winners
        for epoch in range(generations):
            self.calculate_fitness()
            scores = [self.evaluate(p.last_features, self.novel_backlog, self.novel_pop) for p in self.population]
            sort_fitness = np.argsort(scores)[::-1]
            self.population = [self.population[i] for i in sort_fitness]
            fittest_individual = self.population[0]
            if (epoch+1) % checkpoint == 0:
                print('epoch %d, fittest individual %d with accuracy %f'%(epoch+1, sort_fitness[0], 
                                                                          fittest_individual.fitness))
            next_population = [self.population[i] for i in range(n_winners)]
            total_fitness = np.sum([np.abs(i.fitness) for i in self.population])
            parent_probabilities = [np.abs(i.fitness / total_fitness) for i in self.population]
            parents = np.random.choice(self.population, size=n_parents, p=parent_probabilities, replace=False)
            
            for p in next_population:
                if p.last_features is not None:
                    self._memorize(self.novel_pop, p.last_features, backlog_maxsize)
                    if np.random.randint(0,10) < novelty_search_threshold:
                        self._memorize(self.novel_backlog, p.last_features, novelty_log_maxlen)
                        
            for i in np.arange(0, len(parents), 2):
                child1, child2 = self.crossover(parents[i], parents[i+1])
                next_population += [self.mutate(child1), self.mutate(child2)]
            self.population = next_population
            
            if np.random.randint(0,10) < novelty_search_threshold:
                pop_sorted = sorted(self.population, key=lambda p: p.fitness, reverse=True)
                self.generation_backlog.append(pop_sorted[0])
                print('novel add fittest, score: %f, backlog size: %d'%(pop_sorted[0].fitness, 
                                                                        len(self.generation_backlog)))
                generation_backlog_temp = self.generation_backlog
                if len(self.generation_backlog) > backlog_maxsize:
                    generation_backlog_temp = random.sample(generation_backlog, backlog_maxsize)
                for p in generation_backlog_temp:
                    if p.last_features is not None:
                        self._memorize(self.novel_backlog, p.last_features, novelty_log_maxlen)
                        
        return fittest_individual

# %%
population_size = 100
generations = 100
mutation_rate = 0.1
neural_evolve = NeuroEvolution(population_size, mutation_rate, neuralnetwork,
                              window_size, window_size, close, skip, initial_money)

# %%
fittest_nets = neural_evolve.evolve(1)
# Out:
# novel add fittest, score: 37.027929, backlog size: 1

# %%
date = df.Date.values.tolist()
neural_evolve.buy(fittest_nets,date1=date,close=close)
# Out:
# day 17: buy 1 unit at price 232.432434, total balance 9767.567566
# day 20, sell 1 unit at price 238.308304, investment 2.527991 %, total balance 10005.875870,
# day 51: buy 1 unit at price 308.558563, total balance 9697.317307
# day 54, sell 1 unit at price 309.599609, investment 0.337390 %, total balance 10006.916916,
# day 64: buy 1 unit at price 308.903900, total balance 9698.013016
# day 65, sell 1 unit at price 301.946960, investment -2.252137 %, total balance 9999.959976,
# day 67: buy 1 unit at price 292.152161, total balance 9707.807815
# day 69, sell 1 unit at price 298.578583, investment 2.199683 %, total balance 10006.386398,
# day 79: buy 1 unit at price 286.786774, total balance 9719.599624
# day 82, sell 1 unit at price 295.565552, investment 3.061082 %, total balance 10015.165176,
# day 118: buy 1 unit at price 300.480469, total balance 9714.684707
# day 120, sell 1 unit at price 306.306305, investment 1.938840 %, total balance 10020.991012,
# day 124: buy 1 unit at price 309.499512, total balance 9711.491500
# day 125: buy 1 unit at price 308.558563, total balance 9402.932937
# day 128, sell 1 unit at price 314.389404, investment 1.579935 %, total balance 9717.322341,
# day 129, sell 1 unit at price 312.387390, investment 1.240875 %, total balance 10029.709731,
# day 130: buy 1 unit at price 312.422424, total balance 9717.287307
# day 133, sell 1 unit at price 305.410400, investment -2.244405 %, total balance 10022.697707,
# day 156: buy 1 unit at price 290.160156, total balance 9732.537551
# day 159, sell 1 unit at price 291.211212, investment 0.362233 %, total balance 10023.748763,
# day 180: buy 1 unit at price 272.322327, total balance 9751.426436
# day 182, sell 1 unit at price 267.212219, investment -1.876492 %, total balance 10018.638655,
# day 183: buy 1 unit at price 268.163177, total balance 9750.475478
# day 186: buy 1 unit at price 269.109100, total balance 9481.366378
# day 187, sell 1 unit at price 271.601593, investment 1.282210 %, total balance 9752.967971,
# day 188, sell 1 unit at price 267.992981, investment -0.414746 %, total balance 10020.960952,
# day 191: buy 1 unit at price 259.469482, total balance 9761.491470
# day 194, sell 1 unit at price 265.890900, investment 2.474826 %, total balance 10027.382370,
# day 202: buy 1 unit at price 263.063049, total balance 9764.319321
# day 205, sell 1 unit at price 260.790802, investment -0.863765 %, total balance 10025.110123,
# day 225: buy 1 unit at price 266.486481, total balance 9758.623642
# day 226: buy 1 unit at price 267.947937, total balance 9490.675705
# day 228, sell 1 unit at price 266.261261, investment -0.084515 %, total balance 9756.936966,
# day 229, sell 1 unit at price 263.903900, investment -1.509262 %, total balance 10020.840866,
# day 243: buy 1 unit at price 302.147156, total balance 9718.693710
# day 244, sell 1 unit at price 303.688690, investment 0.510193 %, total balance 10022.382400,
# day 249: buy 1 unit at price 273.283295, total balance 9749.099105
# day 251, sell 1 unit at price 274.779785, investment 0.547597 %, total balance 10023.878890,
# day 258: buy 1 unit at price 245.705704, total balance 9778.173186
# day 261, sell 1 unit at price 261.906921, investment 6.593749 %, total balance 10040.080107,
# day 262: buy 1 unit at price 260.280273, total balance 9779.799834
# day 263, sell 1 unit at price 263.693695, investment 1.311441 %, total balance 10043.493529,
# day 266: buy 1 unit at price 270.750763, total balance 9772.742766
# day 267, sell 1 unit at price 266.516510, investment -1.563893 %, total balance 10039.259276,
# day 286: buy 1 unit at price 264.014008, total balance 9775.245268
# day 287, sell 1 unit at price 257.777771, investment -2.362086 %, total balance 10033.023039,
# day 292: buy 1 unit at price 257.817810, total balance 9775.205229
# day 297, sell 1 unit at price 296.136139, investment 14.862561 %, total balance 10071.341368,
# day 318: buy 1 unit at price 306.806793, total balance 9764.534575
# day 319: buy 1 unit at price 308.588593, total balance 9455.945982
# day 320, sell 1 unit at price 306.041046, investment -0.249586 %, total balance 9761.987028,
# day 321, sell 1 unit at price 300.735748, investment -2.544762 %, total balance 10062.722776,
# day 323: buy 1 unit at price 290.760773, total balance 9771.962003
# day 324, sell 1 unit at price 290.290283, investment -0.161813 %, total balance 10062.252286,
# day 353: buy 1 unit at price 329.834839, total balance 9732.417447
# day 354, sell 1 unit at price 325.335327, investment -1.364171 %, total balance 10057.752774,
# day 378: buy 1 unit at price 303.258270, total balance 9754.494504
# day 379, sell 1 unit at price 306.406403, investment 1.038103 %, total balance 10060.900907,
# day 384: buy 1 unit at price 307.307312, total balance 9753.593595
# day 385, sell 1 unit at price 304.274261, investment -0.986977 %, total balance 10057.867856,
# day 396: buy 1 unit at price 303.873871, total balance 9753.993985
# day 397, sell 1 unit at price 300.425415, investment -1.134831 %, total balance 10054.419400,
# day 398: buy 1 unit at price 302.877869, total balance 9751.541531
# day 404, sell 1 unit at price 317.062073, investment 4.683143 %, total balance 10068.603604,
# day 415: buy 1 unit at price 317.892883, total balance 9750.710721
# day 416, sell 1 unit at price 316.476471, investment -0.445563 %, total balance 10067.187192,
# day 429: buy 1 unit at price 305.165161, total balance 9762.022031
# day 432: buy 1 unit at price 302.727722, total balance 9459.294309
# day 433, sell 1 unit at price 302.517517, investment -0.867610 %, total balance 9761.811826,
# day 437, sell 1 unit at price 304.079071, investment 0.446391 %, total balance 10065.890897,
# day 445: buy 1 unit at price 311.836823, total balance 9754.054074
# day 447, sell 1 unit at price 307.362366, investment -1.434871 %, total balance 10061.416440,
# day 454: buy 1 unit at price 290.720734, total balance 9770.695706
# day 455, sell 1 unit at price 285.775787, investment -1.700927 %, total balance 10056.471493,
# day 459: buy 1 unit at price 289.404419, total balance 9767.067074
# day 462, sell 1 unit at price 282.832825, investment -2.270730 %, total balance 10049.899899,
# day 469: buy 1 unit at price 282.887878, total balance 9767.012021
# day 471, sell 1 unit at price 280.630646, investment -0.797925 %, total balance 10047.642667,
# day 482: buy 1 unit at price 285.880890, total balance 9761.761777
# day 483, sell 1 unit at price 285.525513, investment -0.124309 %, total balance 10047.287290,
# day 510: buy 1 unit at price 338.108093, total balance 9709.179197
# day 511: buy 1 unit at price 335.090088, total balance 9374.089109
# day 514, sell 1 unit at price 339.654663, investment 0.457419 %, total balance 9713.743772,
# day 515: buy 1 unit at price 334.944946, total balance 9378.798826
# day 516, sell 1 unit at price 338.963959, investment 1.156069 %, total balance 9717.762785,
# day 521, sell 1 unit at price 340.700714, investment 1.718422 %, total balance 10058.463499,
# day 549: buy 1 unit at price 370.860870, total balance 9687.602629
# day 550, sell 1 unit at price 372.722717, investment 0.502034 %, total balance 10060.325346,
# day 563: buy 1 unit at price 341.201202, total balance 9719.124144
# day 564, sell 1 unit at price 333.893890, investment -2.141643 %, total balance 10053.018034,
# day 582: buy 1 unit at price 345.860870, total balance 9707.157164
# day 583: buy 1 unit at price 344.254242, total balance 9362.902922
# day 584, sell 1 unit at price 345.910919, investment 0.014471 %, total balance 9708.813841,
# day 585: buy 1 unit at price 342.447449, total balance 9366.366392
# day 587, sell 1 unit at price 348.788788, investment 1.317208 %, total balance 9715.155180,
# day 590, sell 1 unit at price 351.331329, investment 2.594232 %, total balance 10066.486509,
# day 597: buy 1 unit at price 354.789795, total balance 9711.696714
# day 598, sell 1 unit at price 353.498505, investment -0.363959 %, total balance 10065.195219,
# day 613: buy 1 unit at price 352.607605, total balance 9712.587614
# day 614, sell 1 unit at price 351.786774, investment -0.232789 %, total balance 10064.374388,
# day 638: buy 1 unit at price 395.460449, total balance 9668.913939
# day 639, sell 1 unit at price 400.290283, investment 1.221319 %, total balance 10069.204222,
# day 649: buy 1 unit at price 413.068054, total balance 9656.136168
# day 650, sell 1 unit at price 411.181183, investment -0.456794 %, total balance 10067.317351,
# day 652: buy 1 unit at price 404.299286, total balance 9663.018065
# day 653, sell 1 unit at price 406.066071, investment 0.436999 %, total balance 10069.084136,
# day 655: buy 1 unit at price 406.036041, total balance 9663.048095
# day 660, sell 1 unit at price 397.492493, investment -2.104135 %, total balance 10060.540588,
# day 664: buy 1 unit at price 397.932922, total balance 9662.607666
# day 667: buy 1 unit at price 389.214203, total balance 9273.393463
# day 670, sell 1 unit at price 395.420410, investment -0.631391 %, total balance 9668.813873,
# day 673, sell 1 unit at price 391.671661, investment 0.631390 %, total balance 10060.485534,
# day 694: buy 1 unit at price 452.387390, total balance 9608.098144
# day 696, sell 1 unit at price 454.719727, investment 0.515562 %, total balance 10062.817871,
# day 708: buy 1 unit at price 432.752747, total balance 9630.065124
# day 709: buy 1 unit at price 440.305298, total balance 9189.759826
# day 711: buy 1 unit at price 440.345337, total balance 8749.414489
# day 712: buy 1 unit at price 436.426422, total balance 8312.988067
# day 714, sell 1 unit at price 437.957947, investment 1.202812 %, total balance 8750.946014,
# day 715: buy 1 unit at price 443.568573, total balance 8307.377441
# day 716, sell 1 unit at price 450.760773, investment 2.374597 %, total balance 8758.138214,
# day 718, sell 1 unit at price 442.812805, investment 0.560348 %, total balance 9200.951019,
# day 720, sell 1 unit at price 435.330322, investment -0.251153 %, total balance 9636.281341,
# day 721, sell 1 unit at price 433.533539, investment -2.262341 %, total balance 10069.814880,
# day 731: buy 1 unit at price 453.448456, total balance 9616.366424
# day 734: buy 1 unit at price 462.807800, total balance 9153.558624
# day 735: buy 1 unit at price 460.265259, total balance 8693.293365
# day 736, sell 1 unit at price 459.734741, investment 1.386328 %, total balance 9153.028106,
# day 737, sell 1 unit at price 455.795807, investment -1.515098 %, total balance 9608.823913,
# day 738, sell 1 unit at price 448.748749, investment -2.502146 %, total balance 10057.572662,
# day 749: buy 1 unit at price 452.952942, total balance 9604.619720
# day 750: buy 1 unit at price 448.733734, total balance 9155.885986
# day 752, sell 1 unit at price 446.776764, investment -1.363536 %, total balance 9602.662750,
# day 753: buy 1 unit at price 445.650665, total balance 9157.012085
# day 754, sell 1 unit at price 443.198212, investment -1.233587 %, total balance 9600.210297,
# day 755: buy 1 unit at price 441.066071, total balance 9159.144226
# day 756, sell 1 unit at price 435.340332, investment -2.313546 %, total balance 9594.484558,
# day 760, sell 1 unit at price 433.143158, investment -1.796310 %, total balance 10027.627716,
# day 765: buy 1 unit at price 425.500488, total balance 9602.127228
# day 766, sell 1 unit at price 424.699707, investment -0.188197 %, total balance 10026.826935,
# day 786: buy 1 unit at price 439.524536, total balance 9587.302399
# day 790, sell 1 unit at price 444.439453, investment 1.118235 %, total balance 10031.741852,
# day 824: buy 1 unit at price 513.113098, total balance 9518.628754
# day 826, sell 1 unit at price 517.552551, investment 0.865200 %, total balance 10036.181305,
# day 827: buy 1 unit at price 516.461487, total balance 9519.719818
# day 830, sell 1 unit at price 532.087097, investment 3.025513 %, total balance 10051.806915,
# day 854: buy 1 unit at price 553.053040, total balance 9498.753875
# day 857, sell 1 unit at price 571.186157, investment 3.278730 %, total balance 10069.940032,
# day 866: buy 1 unit at price 583.093079, total balance 9486.846953
# day 867, sell 1 unit at price 580.630615, investment -0.422311 %, total balance 10067.477568,
# day 868: buy 1 unit at price 562.477478, total balance 9505.000090
# day 869, sell 1 unit at price 551.166138, investment -2.010985 %, total balance 10056.166228,
# day 871: buy 1 unit at price 554.014038, total balance 9502.152190
# day 874, sell 1 unit at price 567.282288, investment 2.394930 %, total balance 10069.434478,
# day 882: buy 1 unit at price 600.550537, total balance 9468.883941
# day 883: buy 1 unit at price 602.002014, total balance 8866.881927
# day 885, sell 1 unit at price 601.771790, investment 0.203356 %, total balance 9468.653717,
# day 886, sell 1 unit at price 602.657654, investment 0.108910 %, total balance 10071.311371,
# day 906: buy 1 unit at price 599.179199, total balance 9472.132172
# day 908, sell 1 unit at price 579.544556, investment -3.276923 %, total balance 10051.676728,
# day 914: buy 1 unit at price 568.013000, total balance 9483.663728
# day 917, sell 1 unit at price 545.250000, investment -4.007479 %, total balance 10028.913728,
# day 922: buy 1 unit at price 537.760010, total balance 9491.153718
# day 924, sell 1 unit at price 548.700012, investment 2.034365 %, total balance 10039.853730,
# day 941: buy 1 unit at price 526.619995, total balance 9513.233735
# day 942, sell 1 unit at price 538.429993, investment 2.242603 %, total balance 10051.663728,
# day 995: buy 1 unit at price 599.020020, total balance 9452.643708
# day 997, sell 1 unit at price 595.440002, investment -0.597646 %, total balance 10048.083710,
# day 1001: buy 1 unit at price 573.140015, total balance 9474.943695
# day 1006, sell 1 unit at price 572.119995, investment -0.177970 %, total balance 10047.063690,
# day 1032: buy 1 unit at price 597.270020, total balance 9449.793670
# day 1035, sell 1 unit at price 591.179993, investment -1.019644 %, total balance 10040.973663,
# day 1060: buy 1 unit at price 558.940002, total balance 9482.033661
# day 1063, sell 1 unit at price 567.869995, investment 1.597666 %, total balance 10049.903656,
# day 1066: buy 1 unit at price 555.950012, total balance 9493.953644
# day 1067, sell 1 unit at price 551.690002, investment -0.766258 %, total balance 10045.643646,
# day 1079: buy 1 unit at price 547.479980, total balance 9498.163666
# day 1081, sell 1 unit at price 547.729980, investment 0.045664 %, total balance 10045.893646,
# day 1082: buy 1 unit at price 549.080017, total balance 9496.813629
# day 1083, sell 1 unit at price 539.650024, investment -1.717417 %, total balance 10036.463653,
# day 1085: buy 1 unit at price 536.969971, total balance 9499.493682
# day 1087, sell 1 unit at price 528.080017, investment -1.655577 %, total balance 10027.573699,
# day 1094: buy 1 unit at price 498.160004, total balance 9529.413695
# day 1097, sell 1 unit at price 520.039978, investment 4.392158 %, total balance 10049.453673,
# day 1140: buy 1 unit at price 538.650024, total balance 9510.803649
# day 1142, sell 1 unit at price 559.289978, investment 3.831793 %, total balance 10070.093627,
# day 1150: buy 1 unit at price 559.849976, total balance 9510.243651
# day 1151, sell 1 unit at price 555.690002, investment -0.743052 %, total balance 10065.933653,
# day 1166: buy 1 unit at price 549.489990, total balance 9516.443663
# day 1167, sell 1 unit at price 541.309998, investment -1.488652 %, total balance 10057.753661,
# day 1168: buy 1 unit at price 543.950012, total balance 9513.803649
# day 1169, sell 1 unit at price 544.859985, investment 0.167290 %, total balance 10058.663634,
# day 1186: buy 1 unit at price 548.770020, total balance 9509.893614
# day 1187, sell 1 unit at price 551.159973, investment 0.435511 %, total balance 10061.053587,
# day 1197: buy 1 unit at price 546.489990, total balance 9514.563597
# day 1200, sell 1 unit at price 552.510010, investment 1.101579 %, total balance 10067.073607,
# day 1223: buy 1 unit at price 563.390015, total balance 9503.683592
# day 1224: buy 1 unit at price 558.570007, total balance 8945.113585
# day 1226: buy 1 unit at price 553.059998, total balance 8392.053587
# day 1228, sell 1 unit at price 540.039978, investment -4.144560 %, total balance 8932.093565,
# day 1229, sell 1 unit at price 543.299988, investment -2.733770 %, total balance 9475.393553,
# day 1231, sell 1 unit at price 545.619995, investment -1.345243 %, total balance 10021.013548,
# day 1238: buy 1 unit at price 583.960022, total balance 9437.053526
# day 1243, sell 1 unit at price 695.099976, investment 19.032117 %, total balance 10132.153502,
# day 1258: buy 1 unit at price 691.469971, total balance 9440.683531
# day 1260, sell 1 unit at price 689.369995, investment -0.303697 %, total balance 10130.053526,
# day 1262: buy 1 unit at price 688.729980, total balance 9441.323546
# day 1264, sell 1 unit at price 679.479980, investment -1.343052 %, total balance 10120.803526,
# day 1265: buy 1 unit at price 644.030029, total balance 9476.773497
# day 1267, sell 1 unit at price 612.469971, investment -4.900402 %, total balance 10089.243468,
# day 1278: buy 1 unit at price 651.080017, total balance 9438.163451
# day 1279: buy 1 unit at price 655.299988, total balance 8782.863463
# day 1281, sell 1 unit at price 665.070007, investment 2.148736 %, total balance 9447.933470,
# day 1284, sell 1 unit at price 660.919983, investment 0.857622 %, total balance 10108.853453,
# day 1307: buy 1 unit at price 671.799988, total balance 9437.053465
# day 1308, sell 1 unit at price 681.140015, investment 1.390299 %, total balance 10118.193480,
# day 1319: buy 1 unit at price 761.599976, total balance 9356.593504
# day 1320: buy 1 unit at price 754.770020, total balance 8601.823484
# day 1322, sell 1 unit at price 765.250000, investment 0.479257 %, total balance 9367.073484,
# day 1323, sell 1 unit at price 756.530029, investment 0.233185 %, total balance 10123.603513,
# day 1325: buy 1 unit at price 750.419983, total balance 9373.183530
# day 1327, sell 1 unit at price 760.010010, investment 1.277955 %, total balance 10133.193540,
# day 1331: buy 1 unit at price 769.630005, total balance 9363.563535
# day 1332, sell 1 unit at price 769.260010, investment -0.048074 %, total balance 10132.823545,
# day 1368: buy 1 unit at price 718.559998, total balance 9414.263547
# day 1371: buy 1 unit at price 733.619995, total balance 8680.643552
# day 1376, sell 1 unit at price 770.770020, investment 7.265924 %, total balance 9451.413572,
# day 1378: buy 1 unit at price 749.380005, total balance 8702.033567
# day 1379, sell 1 unit at price 730.030029, investment -0.489350 %, total balance 9432.063596,
# day 1380, sell 1 unit at price 703.760010, investment -6.087698 %, total balance 10135.823606,
# day 1409: buy 1 unit at price 755.409973, total balance 9380.413633
# day 1411, sell 1 unit at price 760.049988, investment 0.614238 %, total balance 10140.463621,
# day 1431: buy 1 unit at price 774.919983, total balance 9365.543638
# day 1433, sell 1 unit at price 737.770020, investment -4.794039 %, total balance 10103.313658,
# day 1437: buy 1 unit at price 705.059998, total balance 9398.253660
# day 1439, sell 1 unit at price 714.409973, investment 1.326125 %, total balance 10112.663633,
# day 1442: buy 1 unit at price 714.710022, total balance 9397.953611
# day 1443, sell 1 unit at price 725.179993, investment 1.464926 %, total balance 10123.133604,
# day 1448: buy 1 unit at price 724.830017, total balance 9398.303587
# day 1449, sell 1 unit at price 730.299988, investment 0.754656 %, total balance 10128.603575,
# day 1465: buy 1 unit at price 742.929993, total balance 9385.673582
# day 1466, sell 1 unit at price 742.520020, investment -0.055183 %, total balance 10128.193602,
# day 1467: buy 1 unit at price 733.190002, total balance 9395.003600
# day 1469, sell 1 unit at price 733.250000, investment 0.008183 %, total balance 10128.253600,
# day 1475: buy 1 unit at price 710.469971, total balance 9417.783629
# day 1476, sell 1 unit at price 714.869995, investment 0.619312 %, total balance 10132.653624,
# day 1482: buy 1 unit at price 710.250000, total balance 9422.403624
# day 1486, sell 1 unit at price 717.780029, investment 1.060194 %, total balance 10140.183653,
# day 1506: buy 1 unit at price 806.929993, total balance 9333.253660
# day 1507, sell 1 unit at price 805.229980, investment -0.210677 %, total balance 10138.483640,
# day 1508: buy 1 unit at price 807.479980, total balance 9331.003660
# day 1509, sell 1 unit at price 808.489990, investment 0.125082 %, total balance 10139.493650,
# day 1511: buy 1 unit at price 807.049988, total balance 9332.443662
# day 1512: buy 1 unit at price 805.960022, total balance 8526.483640
# day 1513, sell 1 unit at price 801.190002, investment -0.726100 %, total balance 9327.673642,
# day 1514, sell 1 unit at price 805.419983, investment -0.067006 %, total balance 10133.093625,
# day 1516: buy 1 unit at price 799.650024, total balance 9333.443601
# day 1522, sell 1 unit at price 795.820007, investment -0.478962 %, total balance 10129.263608,
# day 1523: buy 1 unit at price 791.919983, total balance 9337.343625
# day 1524: buy 1 unit at price 789.849976, total balance 8547.493649
# day 1528: buy 1 unit at price 807.989990, total balance 7739.503659
# day 1529, sell 1 unit at price 802.840027, investment 1.378933 %, total balance 8542.343686,
# day 1530: buy 1 unit at price 788.479980, total balance 7753.863706
# day 1532: buy 1 unit at price 788.719971, total balance 6965.143735
# day 1533, sell 1 unit at price 790.460022, investment 0.077236 %, total balance 7755.603757,
# day 1536, sell 1 unit at price 795.390015, investment -1.559422 %, total balance 8550.993772,
# day 1538, sell 1 unit at price 805.030029, investment 2.098982 %, total balance 9356.023801,
# day 1539, sell 1 unit at price 815.950012, investment 3.452435 %, total balance 10171.973813,
# day 1564: buy 1 unit at price 817.349976, total balance 9354.623837
# day 1566, sell 1 unit at price 809.900024, investment -0.911476 %, total balance 10164.523861,
# day 1567: buy 1 unit at price 805.479980, total balance 9359.043881
# day 1568, sell 1 unit at price 788.419983, investment -2.117991 %, total balance 10147.463864,
# day 1573: buy 1 unit at price 805.590027, total balance 9341.873837
# day 1579: buy 1 unit at price 786.159973, total balance 8555.713864
# day 1580, sell 1 unit at price 775.969971, investment -3.676815 %, total balance 9331.683835,
# day 1582: buy 1 unit at price 785.000000, total balance 8546.683835
# day 1583: buy 1 unit at price 779.000000, total balance 7767.683835
# day 1585, sell 1 unit at price 785.789978, investment -0.047064 %, total balance 8553.473813,
# day 1588, sell 1 unit at price 764.330017, investment -2.633119 %, total balance 9317.803830,
# day 1590, sell 1 unit at price 778.219971, investment -0.100132 %, total balance 10096.023801,
# day 1597: buy 1 unit at price 817.890015, total balance 9278.133786
# day 1598, sell 1 unit at price 815.650024, investment -0.273874 %, total balance 10093.783810,
# day 1616: buy 1 unit at price 829.530029, total balance 9264.253781
# day 1617, sell 1 unit at price 830.940002, investment 0.169973 %, total balance 10095.193783,
# day 1647: buy 1 unit at price 844.929993, total balance 9250.263790
# day 1649, sell 1 unit at price 849.849976, investment 0.582295 %, total balance 10100.113766,
# day 1658: buy 1 unit at price 868.390015, total balance 9231.723751
# day 1659: buy 1 unit at price 870.000000, total balance 8361.723751
# day 1661, sell 1 unit at price 867.909973, investment -0.055280 %, total balance 9229.633724,
# day 1662: buy 1 unit at price 850.140015, total balance 8379.493709
# day 1663, sell 1 unit at price 849.799988, investment -2.321840 %, total balance 9229.293697,
# day 1665, sell 1 unit at price 835.140015, investment -1.764415 %, total balance 10064.433712,
# day 1677: buy 1 unit at price 839.880005, total balance 9224.553707
# day 1678, sell 1 unit at price 841.460022, investment 0.188124 %, total balance 10066.013729,
# day 1711: buy 1 unit at price 987.090027, total balance 9078.923702
# day 1713, sell 1 unit at price 996.119995, investment 0.914807 %, total balance 10075.043697,
# day 1714: buy 1 unit at price 1003.880005, total balance 9071.163692
# day 1715: buy 1 unit at price 996.679993, total balance 8074.483699
# day 1716: buy 1 unit at price 1001.500000, total balance 7072.983699
# day 1718, sell 1 unit at price 970.119995, investment -3.362953 %, total balance 8043.103694,
# day 1719, sell 1 unit at price 961.809998, investment -3.498615 %, total balance 9004.913692,
# day 1720, sell 1 unit at price 970.500000, investment -3.095357 %, total balance 9975.413692,
# day 1730: buy 1 unit at price 948.090027, total balance 9027.323665
# day 1734, sell 1 unit at price 919.460022, investment -3.019756 %, total balance 9946.783687,
# day 1736: buy 1 unit at price 927.690002, total balance 9019.093685
# day 1737, sell 1 unit at price 940.809998, investment 1.414265 %, total balance 9959.903683,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
