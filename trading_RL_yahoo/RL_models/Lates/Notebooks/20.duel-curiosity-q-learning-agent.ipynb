# %%
import numpy as np
import pandas as pd
import tensorflow.compat.v1 as tf
import os
import sys
import matplotlib.pyplot as plt
from collections import deque
import random
import seaborn as sns
sns.set()
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From d:\anaconda\envs\chattel\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
df = pd.read_csv('dataset/GOOG.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2010-08-12  242.212219  247.622620  241.496490  246.251251  246.251251
# 1  2010-08-13  244.744751  245.840836  243.248245  243.418411  243.418411
# 2  2010-08-16  242.082077  245.180176  240.490494  243.038040  243.038040
# 3  2010-08-17  244.509506  247.597595  243.258255  245.505508  245.505508
# 4  2010-08-18  245.465469  245.680679  241.016022  241.316315  241.316315
#
#     Volume
# 0  4404700
# 1  3865500
# 2  2607300
# 3  3777600
# 4  5367400

# %%
from collections import deque
import random

class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.X = tf.placeholder(tf.float32, (None, self.state_size))
        self.Y = tf.placeholder(tf.float32, (None, self.state_size))
        self.ACTION = tf.placeholder(tf.float32, (None))
        self.REWARD = tf.placeholder(tf.float32, (None))
        self.batch_size = tf.shape(self.ACTION)[0]
        
        with tf.variable_scope('curiosity_model'):
            action = tf.reshape(self.ACTION, (-1,1))
            state_action = tf.concat([self.X, action], axis=1)
            save_state = tf.identity(self.Y)
            
            feed = tf.layers.dense(state_action, 32, activation=tf.nn.relu)
            self.curiosity_logits = tf.layers.dense(feed, self.state_size)
            self.curiosity_cost = tf.reduce_sum(tf.square(save_state - self.curiosity_logits), axis=1)
            
            self.curiosity_optimizer = tf.train.RMSPropOptimizer(self.LEARNING_RATE)\
            .minimize(tf.reduce_mean(self.curiosity_cost))
        
        total_reward = tf.add(self.curiosity_cost, self.REWARD)
        
        with tf.variable_scope("q_model"):
            with tf.variable_scope("eval_net"):
                x_action = tf.layers.dense(self.X, 128, tf.nn.relu)
                tensor_action, tensor_validation = tf.split(x_action,2,1)
                feed_action = tf.layers.dense(tensor_action, self.OUTPUT_SIZE)
                feed_validation = tf.layers.dense(tensor_validation, 1)
                self.logits = feed_validation + \
                tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
            
            with tf.variable_scope("target_net"):
                y_action = tf.layers.dense(self.Y, 128, tf.nn.relu)
                tensor_action, tensor_validation = tf.split(y_action,2,1)
                feed_action = tf.layers.dense(tensor_action, self.OUTPUT_SIZE)
                feed_validation = tf.layers.dense(tensor_validation, 1)
                y_q = feed_validation + \
                tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
            
            q_target = total_reward + self.GAMMA * tf.reduce_max(y_q, axis=1)
            action = tf.cast(self.ACTION, tf.int32)
            action_indices = tf.stack([tf.range(self.batch_size, dtype=tf.int32), action], axis=1)
            q = tf.gather_nd(params=self.logits, indices=action_indices)
            self.cost = tf.losses.mean_squared_error(labels=q_target, predictions=q)
            self.optimizer = tf.train.RMSPropOptimizer(self.LEARNING_RATE).minimize(
            self.cost, var_list=tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, "q_model/eval_net"))
            
        t_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='q_model/target_net')
        e_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='q_model/eval_net')
        self.target_replace_op = [tf.assign(t, e) for t, e in zip(t_params, e_params)]
        
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def predict(self, inputs):
        return self.sess.run(self.logits, feed_dict={self.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action
    
    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        actions = np.array([a[1] for a in replay])
        rewards = np.array([a[2] for a in replay])
        new_states = np.array([a[3] for a in replay])
        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.target_replace_op)
            
        cost, _ = self.sess.run([self.cost, self.optimizer], feed_dict = {
            self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards
        })
        
        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.curiosity_optimizer, feed_dict = {
                self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards
            })
        return cost
    
    def buy(self,initial_money ,date1,close):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        date1 = date1
        state = self.get_state(0)
        for t in range(0, len(close) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= close[t]:
                inventory.append(close[t])
                initial_money -= close[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                df1 = pd.DataFrame({'Date': date1[t+1], 'Close': [close[t+1]],'RESULT': ['Buy'] })
                if not os.path.isfile('output/20.duel-curiosity-q-learning-agent.csv'):
                    df1.to_csv('output/20.duel-curiosity-q-learning-agent.csv', index=False)
                else:
                    df1.to_csv('output/20.duel-curiosity-q-learning-agent.csv', index=False, mode='a', header=False)
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += close[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
                df2 = pd.DataFrame({'Date': date1[t+1], 'Close': [close[t+1]],'RESULT': ['Sell'] })
                if not os.path.isfile('output/20.duel-curiosity-q-learning-agent.csv'):
                    df2.to_csv('output/20.duel-curiosity-q-learning-agent.csv', index=False)
                else:
                    df2.to_csv('output/20.duel-curiosity-q-learning-agent.csv', index=False, mode='a', header=False)
            else:
                print(
                    'day %d, hold UNIT at price %f,  total balance %f,'
                    % (t+1, close[t+1], initial_money)
                )
                df3 = pd.DataFrame({'Date': date1[t+1], 'Close': [close[t+1]], 'RESULT': ['Hold']})
                if not os.path.isfile('output/20.duel-curiosity-q-learning-agent.csv'):
                    df3.to_csv('output/20.duel-curiosity-q-learning-agent.csv', index=False)
                else:
                    df3.to_csv('output/20.duel-curiosity-q-learning-agent.csv', index=False, mode='a', header=False)
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        print(
                '\ntotal gained %f, total investment %f %%'
                % (initial_money - starting_money, invest)
            )
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                state = next_state
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 1, checkpoint = 1, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-4-3d3997751326>:37: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From d:\anaconda\envs\chattel\lib\site-packages\tensorflow\python\layers\core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From d:\anaconda\envs\chattel\lib\site-packages\tensorflow\python\training\rmsprop.py:123: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# epoch: 1, total rewards: 9034.310678.3, cost: 1312529.250000, total money: 10344.840645

# %%
date = df.Date.values.tolist()
agent.buy(initial_money = initial_money,date1=date,close=close)
# Out:
# day 0: buy 1 unit at price 246.251251, total balance 9753.748749
# day 1, sell 1 unit at price 243.418411, investment -1.150386 %, total balance 9997.167160,
# day 2: buy 1 unit at price 243.038040, total balance 9754.129120
# day 3: buy 1 unit at price 245.505508, total balance 9508.623612
# day 5, sell 1 unit at price 234.219223, investment -3.628575 %, total balance 9742.842835,
# day 6: buy 1 unit at price 231.241241, total balance 9511.601594
# day 7: buy 1 unit at price 232.267273, total balance 9279.334321
# day 8: buy 1 unit at price 225.920914, total balance 9053.413407
# day 9: buy 1 unit at price 227.537537, total balance 8825.875870
# day 10, sell 1 unit at price 225.715714, investment -8.060835 %, total balance 9051.591584,
# day 12, sell 1 unit at price 226.571579, investment -2.019390 %, total balance 9278.163163,
# day 13: buy 1 unit at price 225.235229, total balance 9052.927934
# day 14: buy 1 unit at price 230.395401, total balance 8822.532533
# day 15, sell 1 unit at price 231.821823, investment -0.191783 %, total balance 9054.354356,
# day 16: buy 1 unit at price 235.385391, total balance 8818.968965
# day 17, sell 1 unit at price 232.432434, investment 2.882212 %, total balance 9051.401399,
# day 18, sell 1 unit at price 235.525528, investment 3.510626 %, total balance 9286.926927,
# day 22, sell 1 unit at price 240.455460, investment 6.757482 %, total balance 9527.382387,
# day 23, sell 1 unit at price 240.560562, investment 4.412050 %, total balance 9767.942949,
# day 24, sell 1 unit at price 240.770767, investment 2.287897 %, total balance 10008.713716,
# day 26: buy 1 unit at price 254.394394, total balance 9754.319322
# day 27, sell 1 unit at price 256.987000, investment 1.019129 %, total balance 10011.306322,
# day 33: buy 1 unit at price 264.109100, total balance 9747.197222
# day 34: buy 1 unit at price 263.158173, total balance 9484.039049
# day 35, sell 1 unit at price 263.073059, investment -0.392278 %, total balance 9747.112108,
# day 36, sell 1 unit at price 261.436432, investment -0.654261 %, total balance 10008.548540,
# day 39: buy 1 unit at price 265.270264, total balance 9743.278276
# day 40, sell 1 unit at price 268.443451, investment 1.196209 %, total balance 10011.721727,
# day 49: buy 1 unit at price 306.301300, total balance 9705.420427
# day 50: buy 1 unit at price 306.571564, total balance 9398.848863
# day 51: buy 1 unit at price 308.558563, total balance 9090.290300
# day 56, sell 1 unit at price 307.807800, investment 0.491836 %, total balance 9398.098100,
# day 57: buy 1 unit at price 308.108093, total balance 9089.990007
# day 60: buy 1 unit at price 312.852844, total balance 8777.137163
# day 62, sell 1 unit at price 312.722717, investment 2.006433 %, total balance 9089.859880,
# day 63, sell 1 unit at price 311.751740, investment 1.034869 %, total balance 9401.611620,
# day 64, sell 1 unit at price 308.903900, investment 0.258288 %, total balance 9710.515520,
# day 66: buy 1 unit at price 298.033020, total balance 9412.482500
# day 67, sell 1 unit at price 292.152161, investment -6.616748 %, total balance 9704.634661,
# day 68, sell 1 unit at price 292.067078, investment -2.001772 %, total balance 9996.701739,
# day 71: buy 1 unit at price 295.905914, total balance 9700.795825
# day 74, sell 1 unit at price 295.295288, investment -0.206358 %, total balance 9996.091113,
# day 77: buy 1 unit at price 282.457458, total balance 9713.633655
# day 80, sell 1 unit at price 289.469482, investment 2.482506 %, total balance 10003.103137,
# day 81: buy 1 unit at price 293.863861, total balance 9709.239276
# day 82: buy 1 unit at price 295.565552, total balance 9413.673724
# day 85: buy 1 unit at price 297.607605, total balance 9116.066119
# day 87, sell 1 unit at price 295.445435, investment 0.538200 %, total balance 9411.511554,
# day 88, sell 1 unit at price 296.151154, investment 0.198129 %, total balance 9707.662708,
# day 89, sell 1 unit at price 295.695709, investment -0.642422 %, total balance 10003.358417,
# day 101: buy 1 unit at price 304.839844, total balance 9698.518573
# day 102, sell 1 unit at price 307.057068, investment 0.727341 %, total balance 10005.575641,
# day 106: buy 1 unit at price 308.743744, total balance 9696.831897
# day 109: buy 1 unit at price 320.135132, total balance 9376.696765
# day 112, sell 1 unit at price 306.221222, investment -0.817028 %, total balance 9682.917987,
# day 113, sell 1 unit at price 305.845856, investment -4.463514 %, total balance 9988.763843,
# day 116: buy 1 unit at price 308.703705, total balance 9680.060138
# day 118, sell 1 unit at price 300.480469, investment -2.663796 %, total balance 9980.540607,
# day 124: buy 1 unit at price 309.499512, total balance 9671.041095
# day 125, sell 1 unit at price 308.558563, investment -0.304023 %, total balance 9979.599658,
# day 136: buy 1 unit at price 305.325317, total balance 9674.274341
# day 137, sell 1 unit at price 307.007019, investment 0.550790 %, total balance 9981.281360,
# day 139: buy 1 unit at price 300.695709, total balance 9680.585651
# day 140, sell 1 unit at price 305.085083, investment 1.459739 %, total balance 9985.670734,
# day 151: buy 1 unit at price 280.810822, total balance 9704.859912
# day 153: buy 1 unit at price 288.948944, total balance 9415.910968
# day 154, sell 1 unit at price 291.371368, investment 3.760733 %, total balance 9707.282336,
# day 155, sell 1 unit at price 293.738739, investment 1.657661 %, total balance 10001.021075,
# day 160: buy 1 unit at price 293.673676, total balance 9707.347399
# day 161: buy 1 unit at price 296.196198, total balance 9411.151201
# day 162, sell 1 unit at price 294.134125, investment 0.156789 %, total balance 9705.285326,
# day 165: buy 1 unit at price 290.290283, total balance 9414.995043
# day 166: buy 1 unit at price 289.369354, total balance 9125.625689
# day 167, sell 1 unit at price 288.973969, investment -2.438326 %, total balance 9414.599658,
# day 169: buy 1 unit at price 288.428436, total balance 9126.171222
# day 170: buy 1 unit at price 289.544556, total balance 8836.626666
# day 174: buy 1 unit at price 263.128143, total balance 8573.498523
# day 175, sell 1 unit at price 262.812805, investment -9.465518 %, total balance 8836.311328,
# day 176, sell 1 unit at price 262.787781, investment -9.186036 %, total balance 9099.099109,
# day 177, sell 1 unit at price 266.676666, investment -7.541479 %, total balance 9365.775775,
# day 178: buy 1 unit at price 269.149139, total balance 9096.626636
# day 180, sell 1 unit at price 272.322327, investment -5.948041 %, total balance 9368.948963,
# day 182: buy 1 unit at price 267.212219, total balance 9101.736744
# day 184: buy 1 unit at price 267.402405, total balance 8834.334339
# day 185, sell 1 unit at price 267.917908, investment 1.820316 %, total balance 9102.252247,
# day 187: buy 1 unit at price 271.601593, total balance 8830.650654
# day 188: buy 1 unit at price 267.992981, total balance 8562.657673
# day 189, sell 1 unit at price 267.792786, investment -0.503941 %, total balance 8830.450459,
# day 190, sell 1 unit at price 265.040039, investment -0.812904 %, total balance 9095.490498,
# day 191: buy 1 unit at price 259.469482, total balance 8836.021016
# day 192: buy 1 unit at price 265.495483, total balance 8570.525533
# day 193, sell 1 unit at price 265.170166, investment -0.834786 %, total balance 8835.695699,
# day 196, sell 1 unit at price 259.454468, investment -4.472406 %, total balance 9095.150167,
# day 198, sell 1 unit at price 260.095093, investment -2.947050 %, total balance 9355.245260,
# day 199, sell 1 unit at price 259.324310, investment -0.055950 %, total balance 9614.569570,
# day 200: buy 1 unit at price 260.710724, total balance 9353.858846
# day 202, sell 1 unit at price 263.063049, investment -0.916187 %, total balance 9616.921895,
# day 204: buy 1 unit at price 261.801788, total balance 9355.120107
# day 205: buy 1 unit at price 260.790802, total balance 9094.329305
# day 208: buy 1 unit at price 258.623627, total balance 8835.705678
# day 209, sell 1 unit at price 255.010010, investment -2.186605 %, total balance 9090.715688,
# day 210: buy 1 unit at price 252.617615, total balance 8838.098073
# day 211, sell 1 unit at price 254.439438, investment -2.812185 %, total balance 9092.537511,
# day 212: buy 1 unit at price 251.726730, total balance 8840.810781
# day 216: buy 1 unit at price 246.746750, total balance 8594.064031
# day 218, sell 1 unit at price 240.350357, investment -7.837870 %, total balance 8834.414388,
# day 219, sell 1 unit at price 237.677673, investment -8.099010 %, total balance 9072.092061,
# day 221: buy 1 unit at price 247.072067, total balance 8825.019994
# day 222, sell 1 unit at price 249.034027, investment -1.418582 %, total balance 9074.054021,
# day 223, sell 1 unit at price 253.443451, investment 0.681978 %, total balance 9327.497472,
# day 224: buy 1 unit at price 260.775787, total balance 9066.721685
# day 226, sell 1 unit at price 267.947937, investment 8.592286 %, total balance 9334.669622,
# day 228: buy 1 unit at price 266.261261, total balance 9068.408361
# day 230, sell 1 unit at price 267.272278, investment 8.175838 %, total balance 9335.680639,
# day 231: buy 1 unit at price 269.399414, total balance 9066.281225
# day 232: buy 1 unit at price 264.734741, total balance 8801.546484
# day 233: buy 1 unit at price 299.109100, total balance 8502.437384
# day 234, sell 1 unit at price 297.767761, investment 14.185356 %, total balance 8800.205145,
# day 235: buy 1 unit at price 301.576569, total balance 8498.628576
# day 236, sell 1 unit at price 297.972961, investment 11.909994 %, total balance 8796.601537,
# day 237, sell 1 unit at price 303.798798, investment 12.768916 %, total balance 9100.400335,
# day 240, sell 1 unit at price 311.571564, investment 17.691982 %, total balance 9411.971899,
# day 241, sell 1 unit at price 303.913910, investment 1.606374 %, total balance 9715.885809,
# day 242, sell 1 unit at price 305.775787, investment 1.392422 %, total balance 10021.661596,
# day 243: buy 1 unit at price 302.147156, total balance 9719.514440
# day 244, sell 1 unit at price 303.688690, investment 0.510193 %, total balance 10023.203130,
# day 245: buy 1 unit at price 296.496490, total balance 9726.706640
# day 246, sell 1 unit at price 300.885895, investment 1.480424 %, total balance 10027.592535,
# day 249: buy 1 unit at price 273.283295, total balance 9754.309240
# day 250: buy 1 unit at price 286.992004, total balance 9467.317236
# day 251: buy 1 unit at price 274.779785, total balance 9192.537451
# day 252, sell 1 unit at price 281.346344, investment 2.950436 %, total balance 9473.883795,
# day 253, sell 1 unit at price 282.167175, investment -1.681172 %, total balance 9756.050970,
# day 255: buy 1 unit at price 269.769775, total balance 9486.281195
# day 256, sell 1 unit at price 266.841827, investment -2.888844 %, total balance 9753.123022,
# day 257, sell 1 unit at price 252.692688, investment -6.330245 %, total balance 10005.815710,
# day 258: buy 1 unit at price 245.705704, total balance 9760.110006
# day 261, sell 1 unit at price 261.906921, investment 6.593749 %, total balance 10022.016927,
# day 263: buy 1 unit at price 263.693695, total balance 9758.323232
# day 264: buy 1 unit at price 269.809814, total balance 9488.513418
# day 267, sell 1 unit at price 266.516510, investment 1.070490 %, total balance 9755.029928,
# day 268: buy 1 unit at price 262.682678, total balance 9492.347250
# day 269: buy 1 unit at price 261.351349, total balance 9230.995901
# day 271, sell 1 unit at price 267.747742, investment -0.764269 %, total balance 9498.743643,
# day 272: buy 1 unit at price 262.687683, total balance 9236.055960
# day 273, sell 1 unit at price 265.325317, investment 1.006020 %, total balance 9501.381277,
# day 274, sell 1 unit at price 265.025024, investment 1.405646 %, total balance 9766.406301,
# day 275, sell 1 unit at price 266.301300, investment 1.375632 %, total balance 10032.707601,
# day 280: buy 1 unit at price 269.869873, total balance 9762.837728
# day 281, sell 1 unit at price 260.590576, investment -3.438434 %, total balance 10023.428304,
# day 284: buy 1 unit at price 269.939941, total balance 9753.488363
# day 285: buy 1 unit at price 264.684692, total balance 9488.803671
# day 286: buy 1 unit at price 264.014008, total balance 9224.789663
# day 288: buy 1 unit at price 248.008011, total balance 8976.781652
# day 289: buy 1 unit at price 251.201202, total balance 8725.580450
# day 290: buy 1 unit at price 252.602600, total balance 8472.977850
# day 291: buy 1 unit at price 257.612610, total balance 8215.365240
# day 293: buy 1 unit at price 268.853851, total balance 7946.511389
# day 296, sell 1 unit at price 279.774780, investment 3.643343 %, total balance 8226.286169,
# day 297: buy 1 unit at price 296.136139, total balance 7930.150030
# day 299: buy 1 unit at price 295.550537, total balance 7634.599493
# day 303: buy 1 unit at price 298.508514, total balance 7336.090979
# day 304: buy 1 unit at price 291.871857, total balance 7044.219122
# day 305: buy 1 unit at price 293.448456, total balance 6750.770666
# day 306, sell 1 unit at price 299.634644, investment 13.204372 %, total balance 7050.405310,
# day 307, sell 1 unit at price 300.370361, investment 13.770615 %, total balance 7350.775671,
# day 310, sell 1 unit at price 292.702698, investment 18.021469 %, total balance 7643.478369,
# day 311, sell 1 unit at price 299.049042, investment 19.047616 %, total balance 7942.527411,
# day 312: buy 1 unit at price 298.368378, total balance 7644.159033
# day 314, sell 1 unit at price 306.476471, investment 21.327520 %, total balance 7950.635504,
# day 317, sell 1 unit at price 304.479492, investment 18.192775 %, total balance 8255.114996,
# day 318, sell 1 unit at price 306.806793, investment 14.116570 %, total balance 8561.921789,
# day 319, sell 1 unit at price 308.588593, investment 4.204976 %, total balance 8870.510382,
# day 323: buy 1 unit at price 290.760773, total balance 8579.749609
# day 324, sell 1 unit at price 290.290283, investment -1.779815 %, total balance 8870.039892,
# day 325: buy 1 unit at price 285.340332, total balance 8584.699560
# day 326, sell 1 unit at price 281.781769, investment -5.603440 %, total balance 8866.481329,
# day 328, sell 1 unit at price 291.756744, investment -0.039440 %, total balance 9158.238073,
# day 329, sell 1 unit at price 299.994995, investment 2.230899 %, total balance 9458.233068,
# day 330: buy 1 unit at price 307.192200, total balance 9151.040868
# day 333: buy 1 unit at price 312.197205, total balance 8838.843663
# day 335: buy 1 unit at price 308.333344, total balance 8530.510319
# day 337, sell 1 unit at price 313.007996, investment 4.906558 %, total balance 8843.518315,
# day 338, sell 1 unit at price 313.128143, investment 7.692706 %, total balance 9156.646458,
# day 339: buy 1 unit at price 309.344330, total balance 8847.302128
# day 341, sell 1 unit at price 313.293304, investment 9.796362 %, total balance 9160.595432,
# day 342, sell 1 unit at price 311.226227, investment 1.313193 %, total balance 9471.821659,
# day 343: buy 1 unit at price 315.500488, total balance 9156.321171
# day 344, sell 1 unit at price 313.223236, investment 0.328648 %, total balance 9469.544407,
# day 346, sell 1 unit at price 316.886902, investment 2.774127 %, total balance 9786.431309,
# day 347: buy 1 unit at price 320.445435, total balance 9465.985874
# day 350: buy 1 unit at price 323.273285, total balance 9142.712589
# day 351, sell 1 unit at price 333.038025, investment 7.659327 %, total balance 9475.750614,
# day 352: buy 1 unit at price 334.474487, total balance 9141.276127
# day 353, sell 1 unit at price 329.834839, investment 4.543369 %, total balance 9471.110966,
# day 354, sell 1 unit at price 325.335327, investment 1.525967 %, total balance 9796.446293,
# day 358: buy 1 unit at price 315.135132, total balance 9481.311161
# day 359, sell 1 unit at price 312.807800, investment -3.237349 %, total balance 9794.118961,
# day 360: buy 1 unit at price 314.604614, total balance 9479.514347
# day 361: buy 1 unit at price 316.771759, total balance 9162.742588
# day 363: buy 1 unit at price 293.288300, total balance 8869.454288
# day 364: buy 1 unit at price 293.053040, total balance 8576.401248
# day 365, sell 1 unit at price 290.755768, investment -13.070868 %, total balance 8867.157016,
# day 366, sell 1 unit at price 285.030029, investment -9.553077 %, total balance 9152.187045,
# day 369, sell 1 unit at price 289.134125, investment -8.096032 %, total balance 9441.321170,
# day 371, sell 1 unit at price 290.705719, investment -8.228650 %, total balance 9732.026889,
# day 372: buy 1 unit at price 292.847839, total balance 9439.179050
# day 375, sell 1 unit at price 303.688690, investment 3.546132 %, total balance 9742.867740,
# day 376: buy 1 unit at price 305.230225, total balance 9437.637515
# day 377: buy 1 unit at price 306.036041, total balance 9131.601474
# day 379: buy 1 unit at price 306.406403, total balance 8825.195071
# day 381, sell 1 unit at price 303.083069, investment 3.422599 %, total balance 9128.278140,
# day 384, sell 1 unit at price 307.307312, investment 4.937538 %, total balance 9435.585452,
# day 386: buy 1 unit at price 303.358368, total balance 9132.227084
# day 389: buy 1 unit at price 309.504517, total balance 8822.722567
# day 390, sell 1 unit at price 309.434448, investment 1.377394 %, total balance 9132.157015,
# day 391: buy 1 unit at price 311.511505, total balance 8820.645510
# day 392, sell 1 unit at price 310.935944, investment 1.601087 %, total balance 9131.581454,
# day 395, sell 1 unit at price 303.703705, investment -0.882063 %, total balance 9435.285159,
# day 397: buy 1 unit at price 300.425415, total balance 9134.859744
# day 398: buy 1 unit at price 302.877869, total balance 8831.981875
# day 400, sell 1 unit at price 308.303314, investment 1.630067 %, total balance 9140.285189,
# day 403, sell 1 unit at price 317.307312, investment 2.521060 %, total balance 9457.592501,
# day 404: buy 1 unit at price 317.062073, total balance 9140.530428
# day 405, sell 1 unit at price 320.310303, investment 2.824550 %, total balance 9460.840731,
# day 411: buy 1 unit at price 324.529541, total balance 9136.311190
# day 412: buy 1 unit at price 320.940948, total balance 8815.370242
# day 413, sell 1 unit at price 323.783783, investment 7.775097 %, total balance 9139.154025,
# day 414, sell 1 unit at price 321.631622, investment 6.191853 %, total balance 9460.785647,
# day 415: buy 1 unit at price 317.892883, total balance 9142.892764
# day 417: buy 1 unit at price 315.735748, total balance 8827.157016
# day 419: buy 1 unit at price 318.298309, total balance 8508.858707
# day 420, sell 1 unit at price 325.830841, investment 2.765631 %, total balance 8834.689548,
# day 423, sell 1 unit at price 305.090088, investment -5.990041 %, total balance 9139.779636,
# day 425: buy 1 unit at price 299.949951, total balance 8839.829685
# day 426, sell 1 unit at price 298.328339, investment -7.045723 %, total balance 9138.158024,
# day 427, sell 1 unit at price 299.099091, investment -5.911989 %, total balance 9437.257115,
# day 428: buy 1 unit at price 300.935944, total balance 9136.321171
# day 431: buy 1 unit at price 307.797791, total balance 8828.523380
# day 432, sell 1 unit at price 302.727722, investment -4.119909 %, total balance 9131.251102,
# day 433, sell 1 unit at price 302.517517, investment -4.957862 %, total balance 9433.768619,
# day 435: buy 1 unit at price 305.815826, total balance 9127.952793
# day 436: buy 1 unit at price 298.783783, total balance 8829.169010
# day 437: buy 1 unit at price 304.079071, total balance 8525.089939
# day 438: buy 1 unit at price 306.701691, total balance 8218.388248
# day 439: buy 1 unit at price 304.879883, total balance 7913.508365
# day 440: buy 1 unit at price 307.137146, total balance 7606.371219
# day 441: buy 1 unit at price 302.917908, total balance 7303.453311
# day 443: buy 1 unit at price 305.860870, total balance 6997.592441
# day 445, sell 1 unit at price 311.836823, investment 3.962952 %, total balance 7309.429264,
# day 446: buy 1 unit at price 300.500488, total balance 7008.928776
# day 447: buy 1 unit at price 307.362366, total balance 6701.566410
# day 448: buy 1 unit at price 300.700714, total balance 6400.865696
# day 449, sell 1 unit at price 305.035034, investment 1.362114 %, total balance 6705.900730,
# day 450: buy 1 unit at price 302.132141, total balance 6403.768589
# day 451, sell 1 unit at price 296.061066, investment -3.813128 %, total balance 6699.829655,
# day 455, sell 1 unit at price 285.775787, investment -6.552976 %, total balance 6985.605442,
# day 457: buy 1 unit at price 285.490479, total balance 6700.114963
# day 458, sell 1 unit at price 290.575562, investment -2.747211 %, total balance 6990.690525,
# day 461, sell 1 unit at price 284.534546, investment -6.427448 %, total balance 7275.225071,
# day 462: buy 1 unit at price 282.832825, total balance 6992.392246
# day 463: buy 1 unit at price 280.825836, total balance 6711.566410
# day 464: buy 1 unit at price 279.804810, total balance 6431.761600
# day 465: buy 1 unit at price 282.537537, total balance 6149.224063
# day 466: buy 1 unit at price 285.710724, total balance 5863.513339
# day 467: buy 1 unit at price 291.056061, total balance 5572.457278
# day 469: buy 1 unit at price 282.887878, total balance 5289.569400
# day 470: buy 1 unit at price 286.026031, total balance 5003.543369
# day 471: buy 1 unit at price 280.630646, total balance 4722.912723
# day 477, sell 1 unit at price 294.209198, investment -4.073174 %, total balance 5017.121921,
# day 481: buy 1 unit at price 291.141144, total balance 4725.980777
# day 482: buy 1 unit at price 285.880890, total balance 4440.099887
# day 483, sell 1 unit at price 285.525513, investment -6.348195 %, total balance 4725.625400,
# day 484: buy 1 unit at price 288.548553, total balance 4437.076847
# day 485, sell 1 unit at price 287.747742, investment -6.312947 %, total balance 4724.824589,
# day 486: buy 1 unit at price 288.653656, total balance 4436.170933
# day 487: buy 1 unit at price 290.670685, total balance 4145.500248
# day 488: buy 1 unit at price 296.826813, total balance 3848.673435
# day 489, sell 1 unit at price 305.715729, investment 0.923624 %, total balance 4154.389164,
# day 490: buy 1 unit at price 308.063049, total balance 3846.326115
# day 491, sell 1 unit at price 304.089081, investment -0.579279 %, total balance 4150.415196,
# day 492: buy 1 unit at price 304.299286, total balance 3846.115910
# day 494, sell 1 unit at price 317.797791, investment 5.756165 %, total balance 4163.913701,
# day 495: buy 1 unit at price 316.466461, total balance 3847.447240
# day 497, sell 1 unit at price 316.656647, investment 3.023884 %, total balance 4164.103887,
# day 498: buy 1 unit at price 314.689697, total balance 3849.414190
# day 499: buy 1 unit at price 320.985992, total balance 3528.428198
# day 500, sell 1 unit at price 321.731720, investment 6.993999 %, total balance 3850.159918,
# day 502, sell 1 unit at price 321.436432, investment 6.389354 %, total balance 4171.596350,
# day 504, sell 1 unit at price 321.321320, investment 12.550626 %, total balance 4492.917670,
# day 505, sell 1 unit at price 330.335327, investment 16.795258 %, total balance 4823.252997,
# day 506: buy 1 unit at price 334.664673, total balance 4488.588324
# day 508, sell 1 unit at price 336.771759, investment 19.921929 %, total balance 4825.360083,
# day 509: buy 1 unit at price 338.908905, total balance 4486.451178
# day 510, sell 1 unit at price 338.108093, investment 20.837127 %, total balance 4824.559271,
# day 514, sell 1 unit at price 339.654663, investment 20.215766 %, total balance 5164.213934,
# day 515, sell 1 unit at price 334.944946, investment 17.232193 %, total balance 5499.158880,
# day 517: buy 1 unit at price 344.349335, total balance 5154.809545
# day 518, sell 1 unit at price 341.181183, investment 17.221810 %, total balance 5495.990728,
# day 519: buy 1 unit at price 342.887878, total balance 5153.102850
# day 520: buy 1 unit at price 340.860870, total balance 4812.241980
# day 523: buy 1 unit at price 353.428436, total balance 4458.813544
# day 524: buy 1 unit at price 350.735748, total balance 4108.077796
# day 525, sell 1 unit at price 346.441437, investment 22.465989 %, total balance 4454.519233,
# day 527, sell 1 unit at price 353.373383, investment 23.545882 %, total balance 4807.892616,
# day 528: buy 1 unit at price 355.195190, total balance 4452.697426
# day 529: buy 1 unit at price 355.345337, total balance 4097.352089
# day 532, sell 1 unit at price 364.424438, investment 29.859102 %, total balance 4461.776527,
# day 534: buy 1 unit at price 375.065063, total balance 4086.711464
# day 535, sell 1 unit at price 374.954956, investment 28.788034 %, total balance 4461.666420,
# day 536: buy 1 unit at price 377.107117, total balance 4084.559303
# day 538, sell 1 unit at price 377.627625, investment 32.092644 %, total balance 4462.186928,
# day 539: buy 1 unit at price 381.271271, total balance 4080.915657
# day 540: buy 1 unit at price 378.873871, total balance 3702.041786
# day 541: buy 1 unit at price 381.631622, total balance 3320.410164
# day 542, sell 1 unit at price 384.409424, investment 33.221747 %, total balance 3704.819588,
# day 543, sell 1 unit at price 384.209198, investment 33.103874 %, total balance 4089.028786,
# day 544: buy 1 unit at price 379.299286, total balance 3709.729500
# day 545: buy 1 unit at price 372.417419, total balance 3337.312081
# day 546, sell 1 unit at price 372.652649, investment 28.204414 %, total balance 3709.964730,
# day 547: buy 1 unit at price 376.116119, total balance 3333.848611
# day 548: buy 1 unit at price 372.747742, total balance 2961.100869
# day 549, sell 1 unit at price 370.860870, investment 24.941836 %, total balance 3331.961739,
# day 550: buy 1 unit at price 372.722717, total balance 2959.239022
# day 551: buy 1 unit at price 378.123108, total balance 2581.115914
# day 554, sell 1 unit at price 339.674683, investment 10.261417 %, total balance 2920.790597,
# day 556, sell 1 unit at price 338.988983, investment 11.399861 %, total balance 3259.779580,
# day 559: buy 1 unit at price 340.490479, total balance 2919.289101
# day 560: buy 1 unit at price 344.139130, total balance 2575.149971
# day 561, sell 1 unit at price 344.304291, investment 8.796455 %, total balance 2919.454262,
# day 562, sell 1 unit at price 341.821808, investment 8.621862 %, total balance 3261.276070,
# day 563, sell 1 unit at price 341.201202, investment 6.297848 %, total balance 3602.477272,
# day 564: buy 1 unit at price 333.893890, total balance 3268.583382
# day 565, sell 1 unit at price 326.471466, investment -2.448184 %, total balance 3595.054848,
# day 566, sell 1 unit at price 331.846832, investment -2.083767 %, total balance 3926.901680,
# day 567: buy 1 unit at price 333.283295, total balance 3593.618385
# day 568, sell 1 unit at price 329.854858, investment -4.209236 %, total balance 3923.473243,
# day 569, sell 1 unit at price 326.601593, investment -4.749741 %, total balance 4250.074836,
# day 575: buy 1 unit at price 334.319305, total balance 3915.755531
# day 576: buy 1 unit at price 330.905914, total balance 3584.849617
# day 577, sell 1 unit at price 335.690704, investment -1.516797 %, total balance 3920.540321,
# day 578: buy 1 unit at price 342.177185, total balance 3578.363136
# day 579: buy 1 unit at price 346.291290, total balance 3232.071846
# day 583: buy 1 unit at price 344.254242, total balance 2887.817604
# day 584: buy 1 unit at price 345.910919, total balance 2541.906685
# day 585: buy 1 unit at price 342.447449, total balance 2199.459236
# day 587, sell 1 unit at price 348.788788, investment -1.312755 %, total balance 2548.248024,
# day 590, sell 1 unit at price 351.331329, investment 0.169809 %, total balance 2899.579353,
# day 591, sell 1 unit at price 360.750763, investment 1.564090 %, total balance 3260.330116,
# day 597: buy 1 unit at price 354.789795, total balance 2905.540321
# day 598, sell 1 unit at price 353.498505, investment -0.519729 %, total balance 3259.038826,
# day 599: buy 1 unit at price 350.355347, total balance 2908.683479
# day 601: buy 1 unit at price 361.987000, total balance 2546.696479
# day 602: buy 1 unit at price 362.197205, total balance 2184.499274
# day 603: buy 1 unit at price 369.354340, total balance 1815.144934
# day 604, sell 1 unit at price 367.742737, investment -1.952282 %, total balance 2182.887671,
# day 605, sell 1 unit at price 367.017029, investment -2.675656 %, total balance 2549.904700,
# day 606: buy 1 unit at price 369.429443, total balance 2180.475257
# day 608, sell 1 unit at price 370.365356, investment -2.860408 %, total balance 2550.840613,
# day 609: buy 1 unit at price 361.987000, total balance 2188.853613
# day 610, sell 1 unit at price 362.827820, investment -4.235196 %, total balance 2551.681433,
# day 612: buy 1 unit at price 356.016022, total balance 2195.665411
# day 614, sell 1 unit at price 351.786774, investment -7.820329 %, total balance 2547.452185,
# day 615: buy 1 unit at price 371.121124, total balance 2176.331061
# day 616, sell 1 unit at price 377.482483, investment -0.478989 %, total balance 2553.813544,
# day 617: buy 1 unit at price 377.212219, total balance 2176.601325
# day 618: buy 1 unit at price 375.740753, total balance 1800.860572
# day 619: buy 1 unit at price 377.217224, total balance 1423.643348
# day 621: buy 1 unit at price 378.223236, total balance 1045.420112
# day 622: buy 1 unit at price 388.188202, total balance 657.231910
# day 623: buy 1 unit at price 379.889893, total balance 277.342017
# day 624, sell 1 unit at price 383.253265, investment 2.909597 %, total balance 660.595282,
# day 630: buy 1 unit at price 391.821808, total balance 268.773474
# day 634, sell 1 unit at price 396.626617, investment 5.453236 %, total balance 665.400091,
# day 635: buy 1 unit at price 398.163177, total balance 267.236914
# day 636, sell 1 unit at price 400.255249, investment 7.379658 %, total balance 667.492163,
# day 637, sell 1 unit at price 395.780792, investment 6.186388 %, total balance 1063.272955,
# day 639, sell 1 unit at price 400.290283, investment 5.862423 %, total balance 1463.563238,
# day 640, sell 1 unit at price 401.001007, investment 17.771577 %, total balance 1864.564245,
# day 642, sell 1 unit at price 411.161163, investment 19.475272 %, total balance 2275.725408,
# day 643: buy 1 unit at price 419.719727, total balance 1856.005681
# day 644, sell 1 unit at price 416.106110, investment 24.622259 %, total balance 2272.111791,
# day 645: buy 1 unit at price 416.716705, total balance 1855.395086
# day 646, sell 1 unit at price 416.176178, investment 24.871599 %, total balance 2271.571264,
# day 647: buy 1 unit at price 417.827820, total balance 1853.743444
# day 648, sell 1 unit at price 414.219208, investment 23.899279 %, total balance 2267.962652,
# day 649, sell 1 unit at price 413.068054, investment 24.829457 %, total balance 2681.030706,
# day 650: buy 1 unit at price 411.181183, total balance 2269.849523
# day 651, sell 1 unit at price 407.557556, investment 19.107168 %, total balance 2677.407079,
# day 653, sell 1 unit at price 406.066071, investment 17.261416 %, total balance 3083.473150,
# day 654: buy 1 unit at price 407.762756, total balance 2675.710394
# day 655, sell 1 unit at price 406.036041, investment 17.946561 %, total balance 3081.746435,
# day 656, sell 1 unit at price 405.560547, investment 17.244217 %, total balance 3487.306982,
# day 658: buy 1 unit at price 406.616608, total balance 3080.690374
# day 659: buy 1 unit at price 401.731720, total balance 2678.958654
# day 660, sell 1 unit at price 397.492493, investment 16.074012 %, total balance 3076.451147,
# day 661: buy 1 unit at price 400.996002, total balance 2675.455145
# day 662: buy 1 unit at price 406.926941, total balance 2268.528204
# day 664, sell 1 unit at price 397.932922, investment 12.160194 %, total balance 2666.461126,
# day 665: buy 1 unit at price 391.916931, total balance 2274.544195
# day 666: buy 1 unit at price 387.812805, total balance 1886.731390
# day 667, sell 1 unit at price 389.214203, investment 11.091270 %, total balance 2275.945593,
# day 668, sell 1 unit at price 395.485474, investment 9.254054 %, total balance 2671.431067,
# day 669: buy 1 unit at price 395.590576, total balance 2275.840491
# day 670, sell 1 unit at price 395.420410, investment 9.172684 %, total balance 2671.260901,
# day 671, sell 1 unit at price 391.356354, investment 5.956885 %, total balance 3062.617255,
# day 672, sell 1 unit at price 397.082092, investment 7.485231 %, total balance 3459.699347,
# day 675: buy 1 unit at price 400.335327, total balance 3059.364020
# day 676: buy 1 unit at price 400.455444, total balance 2658.908576
# day 677, sell 1 unit at price 404.354340, investment 11.704105 %, total balance 3063.262916,
# day 678: buy 1 unit at price 407.132141, total balance 2656.130775
# day 679: buy 1 unit at price 404.954956, total balance 2251.175819
# day 680, sell 1 unit at price 401.111115, investment 12.666591 %, total balance 2652.286934,
# day 682: buy 1 unit at price 412.697693, total balance 2239.589241
# day 683, sell 1 unit at price 410.625641, investment 10.644643 %, total balance 2650.214882,
# day 685: buy 1 unit at price 423.283295, total balance 2226.931587
# day 686, sell 1 unit at price 431.206207, investment 14.313955 %, total balance 2658.137794,
# day 687: buy 1 unit at price 429.044037, total balance 2229.093757
# day 688, sell 1 unit at price 437.252258, investment 16.370730 %, total balance 2666.346015,
# day 689, sell 1 unit at price 436.176178, investment 15.629974 %, total balance 3102.522193,
# day 690: buy 1 unit at price 440.555542, total balance 2661.966651
# day 691: buy 1 unit at price 439.204193, total balance 2222.762458
# day 692: buy 1 unit at price 443.993988, total balance 1778.768470
# day 693: buy 1 unit at price 458.403412, total balance 1320.365058
# day 695, sell 1 unit at price 455.045044, investment 20.311234 %, total balance 1775.410102,
# day 696: buy 1 unit at price 454.719727, total balance 1320.690375
# day 697: buy 1 unit at price 453.938934, total balance 866.751441
# day 698: buy 1 unit at price 445.155151, total balance 421.596290
# day 703, sell 1 unit at price 435.815826, investment 12.269210 %, total balance 857.412116,
# day 705: buy 1 unit at price 434.249237, total balance 423.162879
# day 708, sell 1 unit at price 432.752747, investment 13.915309 %, total balance 855.915626,
# day 709: buy 1 unit at price 440.305298, total balance 415.610328
# day 715, sell 1 unit at price 443.568573, investment 13.206709 %, total balance 859.178901,
# day 716, sell 1 unit at price 450.760773, investment 13.210060 %, total balance 1309.939674,
# day 718, sell 1 unit at price 442.812805, investment 5.502023 %, total balance 1752.752479,
# day 720: buy 1 unit at price 435.330322, total balance 1317.422157
# day 721: buy 1 unit at price 433.533539, total balance 883.888618
# day 722: buy 1 unit at price 437.262268, total balance 446.626350
# day 725, sell 1 unit at price 444.384399, investment 6.639449 %, total balance 891.010749,
# day 726: buy 1 unit at price 441.596588, total balance 449.414161
# day 727, sell 1 unit at price 443.658661, investment 6.182174 %, total balance 893.072822,
# day 728: buy 1 unit at price 447.192200, total balance 445.880622
# day 730, sell 1 unit at price 453.073059, investment 10.188179 %, total balance 898.953681,
# day 733, sell 1 unit at price 461.961975, investment 13.291851 %, total balance 1360.915656,
# day 734, sell 1 unit at price 462.807800, investment 13.819207 %, total balance 1823.723456,
# day 735, sell 1 unit at price 460.265259, investment 14.570306 %, total balance 2283.988715,
# day 737: buy 1 unit at price 455.795807, total balance 1828.192908
# day 738: buy 1 unit at price 448.748749, total balance 1379.444159
# day 742, sell 1 unit at price 444.294281, investment 10.797683 %, total balance 1823.738440,
# day 743: buy 1 unit at price 443.118103, total balance 1380.620337
# day 744: buy 1 unit at price 441.576569, total balance 939.043768
# day 747, sell 1 unit at price 452.562561, investment 11.214696 %, total balance 1391.606329,
# day 748: buy 1 unit at price 453.738739, total balance 937.867590
# day 749, sell 1 unit at price 452.952942, investment 15.573711 %, total balance 1390.820532,
# day 750: buy 1 unit at price 448.733734, total balance 942.086798
# day 751, sell 1 unit at price 445.770782, investment 14.944833 %, total balance 1387.857580,
# day 753, sell 1 unit at price 445.650665, investment 12.654520 %, total balance 1833.508245,
# day 756: buy 1 unit at price 435.340332, total balance 1398.167913
# day 757, sell 1 unit at price 430.260254, investment 7.474965 %, total balance 1828.428167,
# day 760: buy 1 unit at price 433.143158, total balance 1395.285009
# day 762, sell 1 unit at price 437.292297, investment 9.198739 %, total balance 1832.577306,
# day 763: buy 1 unit at price 435.540527, total balance 1397.036779
# day 764: buy 1 unit at price 433.628632, total balance 963.408147
# day 765: buy 1 unit at price 425.500488, total balance 537.907659
# day 766, sell 1 unit at price 424.699707, investment 4.314954 %, total balance 962.607366,
# day 768: buy 1 unit at price 423.873871, total balance 538.733495
# day 769: buy 1 unit at price 430.620605, total balance 108.112890
# day 770, sell 1 unit at price 436.251251, investment 7.728340 %, total balance 544.364141,
# day 771, sell 1 unit at price 440.220215, investment 6.668930 %, total balance 984.584356,
# day 773, sell 1 unit at price 444.469482, investment 5.005203 %, total balance 1429.053838,
# day 774: buy 1 unit at price 444.779785, total balance 984.274053
# day 776, sell 1 unit at price 446.976990, investment 4.179746 %, total balance 1431.251043,
# day 780: buy 1 unit at price 452.112122, total balance 979.138921
# day 782, sell 1 unit at price 452.007019, investment 2.599327 %, total balance 1431.145940,
# day 784: buy 1 unit at price 443.863861, total balance 987.282079
# day 785: buy 1 unit at price 439.054047, total balance 548.228032
# day 786: buy 1 unit at price 439.524536, total balance 108.703496
# day 788, sell 1 unit at price 438.393402, investment -0.184605 %, total balance 547.096898,
# day 789, sell 1 unit at price 443.943939, investment -0.011272 %, total balance 991.040837,
# day 790, sell 1 unit at price 444.439453, investment -3.046216 %, total balance 1435.480290,
# day 792, sell 1 unit at price 436.611603, investment -3.982260 %, total balance 1872.091893,
# day 793: buy 1 unit at price 433.303314, total balance 1438.788579
# day 794, sell 1 unit at price 427.262268, investment -5.876708 %, total balance 1866.050847,
# day 795: buy 1 unit at price 428.358368, total balance 1437.692479
# day 797: buy 1 unit at price 436.431427, total balance 1001.261052
# day 798: buy 1 unit at price 438.493500, total balance 562.767552
# day 800: buy 1 unit at price 449.464478, total balance 113.303074
# day 804, sell 1 unit at price 504.003998, investment 13.219851 %, total balance 617.307072,
# day 805: buy 1 unit at price 516.221191, total balance 101.085881
# day 806, sell 1 unit at price 513.288269, investment 18.201306 %, total balance 614.374150,
# day 808: buy 1 unit at price 508.007996, total balance 106.366154
# day 811, sell 1 unit at price 515.805786, investment 17.147304 %, total balance 622.171940,
# day 813: buy 1 unit at price 513.568542, total balance 108.603398
# day 815, sell 1 unit at price 511.886902, investment 17.585860 %, total balance 620.490300,
# day 816, sell 1 unit at price 504.479492, investment 16.364582 %, total balance 1124.969792,
# day 817: buy 1 unit at price 508.523529, total balance 616.446263
# day 820: buy 1 unit at price 516.751770, total balance 99.694493
# day 826, sell 1 unit at price 517.552551, investment 18.362042 %, total balance 617.247044,
# day 828, sell 1 unit at price 523.488464, investment 18.544499 %, total balance 1140.735508,
# day 830, sell 1 unit at price 532.087097, investment 18.983984 %, total balance 1672.822605,
# day 834, sell 1 unit at price 529.619629, investment 16.196687 %, total balance 2202.442234,
# day 835: buy 1 unit at price 529.199219, total balance 1673.243015
# day 837: buy 1 unit at price 539.609619, total balance 1133.633396
# day 838, sell 1 unit at price 542.872864, investment 20.974792 %, total balance 1676.506260,
# day 839: buy 1 unit at price 539.184204, total balance 1137.322056
# day 840, sell 1 unit at price 535.515503, investment 20.851642 %, total balance 1672.837559,
# day 841: buy 1 unit at price 530.925903, total balance 1141.911656
# day 844: buy 1 unit at price 542.917908, total balance 598.993748
# day 845, sell 1 unit at price 543.653625, investment 23.116502 %, total balance 1142.647373,
# day 846, sell 1 unit at price 550.860840, investment 21.404851 %, total balance 1693.508213,
# day 847, sell 1 unit at price 558.108093, investment 24.374000 %, total balance 2251.616306,
# day 848: buy 1 unit at price 556.476501, total balance 1695.139805
# day 849, sell 1 unit at price 559.289307, investment 28.471742 %, total balance 2254.429112,
# day 851, sell 1 unit at price 555.285278, investment 28.199019 %, total balance 2809.714390,
# day 852: buy 1 unit at price 560.915894, total balance 2248.798496
# day 855, sell 1 unit at price 559.219238, investment 28.396602 %, total balance 2808.017734,
# day 857, sell 1 unit at price 571.186157, investment 31.722427 %, total balance 3379.203891,
# day 858, sell 1 unit at price 565.685669, investment 32.945951 %, total balance 3944.889560,
# day 861, sell 1 unit at price 575.275269, investment 35.718502 %, total balance 4520.164829,
# day 867, sell 1 unit at price 580.630615, investment 34.835772 %, total balance 5100.795444,
# day 868: buy 1 unit at price 562.477478, total balance 4538.317966
# day 870, sell 1 unit at price 562.067078, investment 26.369745 %, total balance 5100.385044,
# day 871: buy 1 unit at price 554.014038, total balance 4546.371006
# day 872, sell 1 unit at price 568.263245, investment 25.690778 %, total balance 5114.634251,
# day 874, sell 1 unit at price 567.282288, investment 27.805469 %, total balance 5681.916539,
# day 877: buy 1 unit at price 580.560547, total balance 5101.355992
# day 879, sell 1 unit at price 587.052063, investment 33.708382 %, total balance 5688.408055,
# day 880, sell 1 unit at price 595.685669, investment 35.529560 %, total balance 6284.093724,
# day 882: buy 1 unit at price 600.550537, total balance 5683.543187
# day 885, sell 1 unit at price 601.771790, investment 38.880034 %, total balance 6285.314977,
# day 886, sell 1 unit at price 602.657654, investment 40.690062 %, total balance 6887.972631,
# day 888, sell 1 unit at price 606.861877, investment 39.050911 %, total balance 7494.834508,
# day 889: buy 1 unit at price 610.610596, total balance 6884.223912
# day 890: buy 1 unit at price 610.695679, total balance 6273.528233
# day 892: buy 1 unit at price 608.433411, total balance 5665.094822
# day 893, sell 1 unit at price 601.946960, investment 37.276142 %, total balance 6267.041782,
# day 894: buy 1 unit at price 608.063049, total balance 5658.978733
# day 895: buy 1 unit at price 609.739746, total balance 5049.238987
# day 896, sell 1 unit at price 610.415405, investment 35.809488 %, total balance 5659.654392,
# day 897, sell 1 unit at price 608.002991, investment 17.779549 %, total balance 6267.657383,
# day 899, sell 1 unit at price 600.595581, investment 18.225616 %, total balance 6868.252964,
# day 900, sell 1 unit at price 604.254272, investment 17.657960 %, total balance 7472.507236,
# day 901: buy 1 unit at price 595.125122, total balance 6877.382114
# day 902, sell 1 unit at price 586.987000, investment 15.429664 %, total balance 7464.369114,
# day 903: buy 1 unit at price 596.646667, total balance 6867.722447
# day 905, sell 1 unit at price 600.225220, investment 16.153491 %, total balance 7467.947667,
# day 906: buy 1 unit at price 599.179199, total balance 6868.768468
# day 907: buy 1 unit at price 592.112122, total balance 6276.656346
# day 908, sell 1 unit at price 579.544556, investment 9.513494 %, total balance 6856.200902,
# day 910: buy 1 unit at price 566.551575, total balance 6289.649327
# day 911: buy 1 unit at price 557.697693, total balance 5731.951634
# day 914, sell 1 unit at price 568.013000, investment 5.263691 %, total balance 6299.964634,
# day 916, sell 1 unit at price 571.500000, investment 5.993461 %, total balance 6871.464634,
# day 918, sell 1 unit at price 540.630005, investment 1.827770 %, total balance 7412.094639,
# day 919: buy 1 unit at price 557.510010, total balance 6854.584629
# day 921, sell 1 unit at price 546.690002, investment 0.694782 %, total balance 7401.274631,
# day 922: buy 1 unit at price 537.760010, total balance 6863.514621
# day 923: buy 1 unit at price 545.200012, total balance 6318.314609
# day 927: buy 1 unit at price 539.369995, total balance 5778.944614
# day 929: buy 1 unit at price 537.510010, total balance 5241.434604
# day 930, sell 1 unit at price 534.440002, investment -3.960005 %, total balance 5775.874606,
# day 931, sell 1 unit at price 523.099976, investment -6.741816 %, total balance 6298.974582,
# day 932, sell 1 unit at price 522.979980, investment -7.022059 %, total balance 6821.954562,
# day 934, sell 1 unit at price 534.880005, investment -3.453709 %, total balance 7356.834567,
# day 935, sell 1 unit at price 538.530029, investment -7.239644 %, total balance 7895.364596,
# day 936: buy 1 unit at price 533.869995, total balance 7361.494601
# day 938, sell 1 unit at price 522.570007, investment -12.984841 %, total balance 7884.064608,
# day 942, sell 1 unit at price 538.429993, investment -11.821053 %, total balance 8422.494601,
# day 943: buy 1 unit at price 541.539978, total balance 7880.954623
# day 944: buy 1 unit at price 534.409973, total balance 7346.544650
# day 945, sell 1 unit at price 529.119995, investment -13.357829 %, total balance 7875.664645,
# day 946, sell 1 unit at price 528.299988, investment -13.170451 %, total balance 8403.964633,
# day 947: buy 1 unit at price 538.830017, total balance 7865.134616
# day 948: buy 1 unit at price 540.390015, total balance 7324.744601
# day 949, sell 1 unit at price 549.700012, investment -9.598188 %, total balance 7874.444613,
# day 950: buy 1 unit at price 555.450012, total balance 7318.994601
# day 951, sell 1 unit at price 563.799988, investment -7.534322 %, total balance 7882.794589,
# day 953, sell 1 unit at price 570.450012, investment -4.146205 %, total balance 8453.244601,
# day 955: buy 1 unit at price 571.650024, total balance 7881.594577
# day 956: buy 1 unit at price 564.340027, total balance 7317.254550
# day 957: buy 1 unit at price 554.510010, total balance 6762.744540
# day 959, sell 1 unit at price 564.929993, investment -5.315822 %, total balance 7327.674533,
# day 960: buy 1 unit at price 566.030029, total balance 6761.644504
# day 961: buy 1 unit at price 570.729980, total balance 6190.914524
# day 964, sell 1 unit at price 559.500000, investment -6.622259 %, total balance 6750.414524,
# day 965, sell 1 unit at price 560.349976, investment -5.364211 %, total balance 7310.764500,
# day 966, sell 1 unit at price 552.299988, investment -2.515497 %, total balance 7863.064488,
# day 968, sell 1 unit at price 560.659973, investment 0.531162 %, total balance 8423.724461,
# day 970, sell 1 unit at price 566.520020, investment 1.616116 %, total balance 8990.244481,
# day 971: buy 1 unit at price 574.289978, total balance 8415.954503
# day 972: buy 1 unit at price 572.539978, total balance 7843.414525
# day 973, sell 1 unit at price 585.929993, investment 8.957524 %, total balance 8429.344518,
# day 978: buy 1 unit at price 590.780029, total balance 7838.564489
# day 979, sell 1 unit at price 593.080017, investment 8.782099 %, total balance 8431.644506,
# day 980, sell 1 unit at price 590.760010, investment 9.527785 %, total balance 9022.404516,
# day 981: buy 1 unit at price 578.400024, total balance 8444.004492
# day 982, sell 1 unit at price 583.359985, investment 8.530069 %, total balance 9027.364477,
# day 983, sell 1 unit at price 580.039978, investment 8.648170 %, total balance 9607.404455,
# day 986, sell 1 unit at price 593.059998, investment 9.513613 %, total balance 10200.464453,
# day 987: buy 1 unit at price 590.619995, total balance 9609.844458
# day 989, sell 1 unit at price 605.109985, investment 13.229546 %, total balance 10214.954443,
# day 991, sell 1 unit at price 603.570007, investment 12.014919 %, total balance 10818.524450,
# day 992, sell 1 unit at price 605.190002, investment 11.991337 %, total balance 11423.714452,
# ...
# day 1405: buy 1 unit at price 750.239990, total balance 3906.234927
# day 1406: buy 1 unit at price 750.570007, total balance 3155.664920
# day 1407, sell 1 unit at price 757.359985, investment -3.372076 %, total balance 3913.024905,
# day 1410: buy 1 unit at price 762.159973, total balance 3150.864932
# day 1411, sell 1 unit at price 760.049988, investment -1.674019 %, total balance 3910.914920,
# day 1412, sell 1 unit at price 757.559998, investment -0.653078 %, total balance 4668.474918,
# day 1415, sell 1 unit at price 765.890015, investment 0.763066 %, total balance 5434.364933,
# day 1417: buy 1 unit at price 762.900024, total balance 4671.464909
# day 1418: buy 1 unit at price 769.669983, total balance 3901.794926
# day 1419, sell 1 unit at price 765.119995, investment -1.476974 %, total balance 4666.914921,
# day 1420: buy 1 unit at price 758.570007, total balance 3908.344914
# day 1422: buy 1 unit at price 760.119995, total balance 3148.224919
# day 1423: buy 1 unit at price 759.469971, total balance 2388.754948
# day 1424: buy 1 unit at price 757.539978, total balance 1631.214970
# day 1427: buy 1 unit at price 775.390015, total balance 855.824955
# day 1428: buy 1 unit at price 780.000000, total balance 75.824955
# day 1430, sell 1 unit at price 776.250000, investment 1.932947 %, total balance 852.074955,
# day 1431: buy 1 unit at price 774.919983, total balance 77.154972
# day 1439, sell 1 unit at price 714.409973, investment -3.588398 %, total balance 791.564945,
# day 1441, sell 1 unit at price 711.369995, investment -1.000613 %, total balance 1502.934940,
# day 1443: buy 1 unit at price 725.179993, total balance 777.754947
# day 1444, sell 1 unit at price 729.130005, investment -0.635055 %, total balance 1506.884952,
# day 1445, sell 1 unit at price 739.380005, investment -2.885660 %, total balance 2246.264957,
# day 1446: buy 1 unit at price 730.549988, total balance 1515.714969
# day 1448: buy 1 unit at price 724.830017, total balance 790.884952
# day 1451, sell 1 unit at price 721.780029, investment -1.130090 %, total balance 1512.664981,
# day 1453, sell 1 unit at price 721.710022, investment 2.173118 %, total balance 2234.375003,
# day 1454: buy 1 unit at price 717.250000, total balance 1517.125003
# day 1458, sell 1 unit at price 747.599976, investment 4.193665 %, total balance 2264.724979,
# day 1460: buy 1 unit at price 748.460022, total balance 1516.264957
# day 1462, sell 1 unit at price 735.859985, investment 1.904142 %, total balance 2252.124942,
# day 1464, sell 1 unit at price 731.090027, investment 1.923915 %, total balance 2983.214969,
# day 1465: buy 1 unit at price 742.929993, total balance 2240.284976
# day 1468: buy 1 unit at price 731.880005, total balance 1508.404971
# day 1469, sell 1 unit at price 733.250000, investment 1.713133 %, total balance 2241.654971,
# day 1470: buy 1 unit at price 732.190002, total balance 1509.464969
# day 1471: buy 1 unit at price 724.250000, total balance 785.214969
# day 1473, sell 1 unit at price 706.130005, investment -3.153115 %, total balance 1491.344974,
# day 1474, sell 1 unit at price 708.880005, investment -2.204561 %, total balance 2200.224979,
# day 1476: buy 1 unit at price 714.869995, total balance 1485.354984
# day 1477: buy 1 unit at price 685.200012, total balance 800.154972
# day 1478: buy 1 unit at price 681.140015, total balance 119.014957
# day 1479, sell 1 unit at price 691.260010, investment -3.619526 %, total balance 810.274967,
# day 1480, sell 1 unit at price 695.190002, investment -2.470537 %, total balance 1505.464969,
# day 1481: buy 1 unit at price 703.530029, total balance 801.934940
# day 1482: buy 1 unit at price 710.250000, total balance 91.684940
# day 1484, sell 1 unit at price 708.969971, investment -0.639084 %, total balance 800.654911,
# day 1485, sell 1 unit at price 707.260010, investment -2.502028 %, total balance 1507.914921,
# day 1487: buy 1 unit at price 727.200012, total balance 780.714909
# day 1488, sell 1 unit at price 732.510010, investment -2.363241 %, total balance 1513.224919,
# day 1490: buy 1 unit at price 735.799988, total balance 777.424931
# day 1491: buy 1 unit at price 735.630005, total balance 41.794926
# day 1494, sell 1 unit at price 757.080017, investment 0.867342 %, total balance 798.874943,
# day 1495: buy 1 unit at price 754.409973, total balance 44.464970
# day 1498, sell 1 unit at price 757.650024, investment -0.591733 %, total balance 802.114994,
# day 1502: buy 1 unit at price 800.940002, total balance 1.174992
# day 1505, sell 1 unit at price 797.250000, investment 4.502553 %, total balance 798.424992,
# day 1512, sell 1 unit at price 805.960022, investment 4.715013 %, total balance 1604.385014,
# day 1513, sell 1 unit at price 801.190002, investment 5.618466 %, total balance 2405.575016,
# day 1515: buy 1 unit at price 802.750000, total balance 1602.825016
# day 1516: buy 1 unit at price 799.650024, total balance 803.174992
# day 1517: buy 1 unit at price 796.950012, total balance 6.224980
# day 1526, sell 1 unit at price 796.869995, investment 4.834763 %, total balance 803.094975,
# day 1528, sell 1 unit at price 807.989990, investment 6.388669 %, total balance 1611.084965,
# day 1529: buy 1 unit at price 802.840027, total balance 808.244938
# day 1534: buy 1 unit at price 801.229980, total balance 7.014958
# day 1538, sell 1 unit at price 805.030029, investment 6.268983 %, total balance 812.044987,
# day 1540, sell 1 unit at price 814.960022, investment 5.103239 %, total balance 1627.005009,
# day 1541, sell 1 unit at price 802.650024, investment 2.903849 %, total balance 2429.655033,
# day 1542: buy 1 unit at price 810.729980, total balance 1618.925053
# day 1544, sell 1 unit at price 802.640015, investment 3.577148 %, total balance 2421.565068,
# day 1546: buy 1 unit at price 800.380005, total balance 1621.185063
# day 1548: buy 1 unit at price 801.229980, total balance 819.955083
# day 1550, sell 1 unit at price 800.710022, investment 10.415349 %, total balance 1620.665105,
# day 1552: buy 1 unit at price 809.570007, total balance 811.095098
# day 1553, sell 1 unit at price 811.770020, investment 11.117656 %, total balance 1622.865118,
# day 1554, sell 1 unit at price 804.080017, investment 10.933598 %, total balance 2426.945135,
# day 1558, sell 1 unit at price 826.840027, investment 15.279195 %, total balance 3253.785162,
# day 1559: buy 1 unit at price 821.630005, total balance 2432.155157
# day 1560, sell 1 unit at price 824.059998, investment 10.100737 %, total balance 3256.215155,
# day 1561, sell 1 unit at price 835.739990, investment 12.492428 %, total balance 4091.955145,
# day 1562: buy 1 unit at price 828.549988, total balance 3263.405157
# day 1563: buy 1 unit at price 822.099976, total balance 2441.305181
# day 1565, sell 1 unit at price 819.559998, investment 11.980105 %, total balance 3260.865179,
# day 1566, sell 1 unit at price 809.900024, investment 10.613368 %, total balance 4070.765203,
# day 1567: buy 1 unit at price 805.479980, total balance 3265.285223
# day 1568, sell 1 unit at price 788.419983, investment 8.860198 %, total balance 4053.705206,
# day 1569: buy 1 unit at price 782.190002, total balance 3271.515204
# day 1570, sell 1 unit at price 781.099976, investment 9.264619 %, total balance 4052.615180,
# day 1574: buy 1 unit at price 780.289978, total balance 3272.325202
# day 1577: buy 1 unit at price 775.159973, total balance 2497.165229
# day 1578, sell 1 unit at price 779.979980, investment 13.832453 %, total balance 3277.145209,
# day 1579, sell 1 unit at price 786.159973, investment 15.418263 %, total balance 4063.305182,
# day 1580: buy 1 unit at price 775.969971, total balance 3287.335211
# day 1581, sell 1 unit at price 784.799988, investment 11.551740 %, total balance 4072.135199,
# day 1582: buy 1 unit at price 785.000000, total balance 3287.135199
# day 1583, sell 1 unit at price 779.000000, investment 9.679690 %, total balance 4066.135199,
# day 1584: buy 1 unit at price 780.229980, total balance 3285.905219
# day 1587: buy 1 unit at price 775.880005, total balance 2510.025214
# day 1588, sell 1 unit at price 764.330017, investment 5.105886 %, total balance 3274.355231,
# day 1589, sell 1 unit at price 764.460022, investment 3.895085 %, total balance 4038.815253,
# day 1590: buy 1 unit at price 778.219971, total balance 3260.595282
# day 1591: buy 1 unit at price 776.179993, total balance 2484.415289
# day 1592, sell 1 unit at price 791.469971, investment 7.590768 %, total balance 3275.885260,
# day 1593: buy 1 unit at price 795.169983, total balance 2480.715277
# day 1594, sell 1 unit at price 809.450012, investment 7.295773 %, total balance 3290.165289,
# day 1595: buy 1 unit at price 807.900024, total balance 2482.265265
# day 1596: buy 1 unit at price 815.340027, total balance 1666.925238
# day 1597, sell 1 unit at price 817.890015, investment 2.116265 %, total balance 2484.815253,
# day 1599: buy 1 unit at price 809.840027, total balance 1674.975226
# day 1600, sell 1 unit at price 812.500000, investment 1.214575 %, total balance 2487.475226,
# day 1601, sell 1 unit at price 815.200012, investment 1.944599 %, total balance 3302.675238,
# day 1604, sell 1 unit at price 807.799988, investment 1.361437 %, total balance 4110.475226,
# day 1605: buy 1 unit at price 809.929993, total balance 3300.545233
# day 1607, sell 1 unit at price 802.880005, investment 0.004980 %, total balance 4103.425238,
# day 1611: buy 1 unit at price 813.020020, total balance 3290.405218
# day 1612: buy 1 unit at price 825.210022, total balance 2465.195196
# day 1613: buy 1 unit at price 827.179993, total balance 1638.015203
# day 1614, sell 1 unit at price 826.010010, investment 3.092749 %, total balance 2464.025213,
# day 1616: buy 1 unit at price 829.530029, total balance 1634.495184
# day 1619, sell 1 unit at price 829.020020, investment 2.255997 %, total balance 2463.515204,
# day 1620: buy 1 unit at price 824.369995, total balance 1639.145209
# day 1622: buy 1 unit at price 844.429993, total balance 794.715216
# day 1628, sell 1 unit at price 820.190002, investment 2.475074 %, total balance 1614.905218,
# day 1629, sell 1 unit at price 815.239990, investment 1.748563 %, total balance 2430.145208,
# day 1630: buy 1 unit at price 818.260010, total balance 1611.885198
# day 1631: buy 1 unit at price 820.130005, total balance 791.755193
# day 1638, sell 1 unit at price 840.030029, investment 3.762494 %, total balance 1631.785222,
# day 1640, sell 1 unit at price 842.169983, investment 2.499906 %, total balance 2473.955205,
# day 1641, sell 1 unit at price 846.549988, investment 2.172470 %, total balance 3320.505193,
# day 1642, sell 1 unit at price 849.270020, investment 3.304956 %, total balance 4169.775213,
# day 1643, sell 1 unit at price 851.359985, investment 5.695983 %, total balance 5021.135198,
# day 1644, sell 1 unit at price 851.000000, investment 8.797095 %, total balance 5872.135198,
# day 1646: buy 1 unit at price 849.669983, total balance 5022.465215
# day 1648, sell 1 unit at price 856.750000, investment 9.798924 %, total balance 5879.215215,
# day 1649: buy 1 unit at price 849.849976, total balance 5029.365239
# day 1650: buy 1 unit at price 849.080017, total balance 4180.285222
# day 1655: buy 1 unit at price 861.409973, total balance 3318.875249
# day 1656: buy 1 unit at price 864.580017, total balance 2454.295232
# day 1658, sell 1 unit at price 868.390015, investment 12.027200 %, total balance 3322.685247,
# day 1659: buy 1 unit at price 870.000000, total balance 2452.685247
# day 1660: buy 1 unit at price 872.369995, total balance 1580.315252
# day 1661: buy 1 unit at price 867.909973, total balance 712.405279
# day 1663, sell 1 unit at price 849.799988, investment 9.514546 %, total balance 1562.205267,
# day 1664, sell 1 unit at price 839.650024, investment 6.961786 %, total balance 2401.855291,
# day 1665, sell 1 unit at price 835.140015, investment 7.037673 %, total balance 3236.995306,
# day 1667: buy 1 unit at price 840.630005, total balance 2396.365301
# day 1668: buy 1 unit at price 849.869995, total balance 1546.495306
# day 1671, sell 1 unit at price 856.750000, investment 10.423003 %, total balance 2403.245306,
# day 1672: buy 1 unit at price 852.570007, total balance 1550.675299
# day 1673: buy 1 unit at price 848.909973, total balance 701.765326
# day 1677, sell 1 unit at price 839.880005, investment 7.923214 %, total balance 1541.645331,
# day 1678, sell 1 unit at price 841.460022, investment 8.410424 %, total balance 2383.105353,
# day 1680: buy 1 unit at price 855.130005, total balance 1527.975348
# day 1681, sell 1 unit at price 853.989990, investment 7.397161 %, total balance 2381.965338,
# day 1682: buy 1 unit at price 856.510010, total balance 1525.455328
# day 1683, sell 1 unit at price 860.080017, investment 6.458719 %, total balance 2385.535345,
# day 1684, sell 1 unit at price 858.950012, investment 5.348687 %, total balance 3244.485357,
# day 1685, sell 1 unit at price 878.929993, investment 8.531310 %, total balance 4123.415350,
# day 1687, sell 1 unit at price 889.140015, investment 9.779860 %, total balance 5012.555365,
# day 1690, sell 1 unit at price 932.820007, investment 14.735183 %, total balance 5945.375372,
# day 1691: buy 1 unit at price 937.090027, total balance 5008.285345
# day 1693: buy 1 unit at price 954.719971, total balance 4053.565374
# day 1694: buy 1 unit at price 950.280029, total balance 3103.285345
# day 1696, sell 1 unit at price 956.710022, investment 15.935337 %, total balance 4059.995367,
# day 1697: buy 1 unit at price 954.840027, total balance 3105.155340
# day 1700: buy 1 unit at price 959.219971, total balance 2145.935369
# day 1702, sell 1 unit at price 942.169983, investment 13.901447 %, total balance 3088.105352,
# day 1703: buy 1 unit at price 950.500000, total balance 2137.605352
# day 1704: buy 1 unit at price 954.650024, total balance 1182.955328
# day 1706: buy 1 unit at price 970.549988, total balance 212.405340
# day 1708, sell 1 unit at price 991.859985, investment 19.568907 %, total balance 1204.265325,
# day 1711, sell 1 unit at price 987.090027, investment 19.738714 %, total balance 2191.355352,
# day 1713, sell 1 unit at price 996.119995, investment 17.963597 %, total balance 3187.475347,
# day 1714: buy 1 unit at price 1003.880005, total balance 2183.595342
# day 1715, sell 1 unit at price 996.679993, investment 21.804803 %, total balance 3180.275335,
# day 1716: buy 1 unit at price 1001.500000, total balance 2178.775335
# day 1718: buy 1 unit at price 970.119995, total balance 1208.655340
# day 1719: buy 1 unit at price 961.809998, total balance 246.845342
# day 1725, sell 1 unit at price 968.989990, investment 18.150779 %, total balance 1215.835332,
# day 1726: buy 1 unit at price 978.590027, total balance 237.245305
# day 1727, sell 1 unit at price 976.619995, investment 14.941096 %, total balance 1213.865300,
# day 1730, sell 1 unit at price 948.090027, investment 11.559693 %, total balance 2161.955327,
# day 1735: buy 1 unit at price 932.260010, total balance 1229.695317
# day 1737: buy 1 unit at price 940.809998, total balance 288.885319
# day 1738, sell 1 unit at price 951.000000, investment 12.003578 %, total balance 1239.885319,
# day 1739, sell 1 unit at price 953.530029, investment 10.694101 %, total balance 2193.415348,
# day 1740, sell 1 unit at price 967.659973, investment 11.922547 %, total balance 3161.075321,
# day 1742, sell 1 unit at price 976.909973, investment 12.288503 %, total balance 4137.985294,
# day 1745: buy 1 unit at price 992.770020, total balance 3145.215274
# day 1748: buy 1 unit at price 998.309998, total balance 2146.905276
# day 1749: buy 1 unit at price 969.030029, total balance 1177.875247
# day 1750, sell 1 unit at price 965.309998, investment 10.653737 %, total balance 2143.185245,
# day 1751: buy 1 unit at price 952.510010, total balance 1190.675235
# day 1753: buy 1 unit at price 945.500000, total balance 245.175235
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-2b752d72cfdb> in <module>
# ----> 1 states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
#
# TypeError: 'NoneType' object is not iterable

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-198b130142b3> in <module>
#       1 fig = plt.figure(figsize = (15,5))
#       2 plt.plot(close, color='r', lw=2.)
# ----> 3 plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
#       4 plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
#       5 plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
#
# NameError: name 'states_buy' is not defined
